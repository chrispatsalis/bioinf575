# %%
import numpy as np
import pandas as pd

# %%
from sqlite3 import connect

'''    
    Establish a connection to the database.
    This statement creates the file iat the given path if it does not exist.
    The file was provided so the statement should just establish the connection.
'''
connection = connect('../Ecoli_ASM584v2_genomic.gff')
cursor = connection.cursor()

# %%
sql = '''SELECT * FROM sqlite_master;'''
cursor.execute(sql)
cursor.description
# Out:
# (('type', None, None, None, None, None, None),
#  ('name', None, None, None, None, None, None),
#  ('tbl_name', None, None, None, None, None, None),
#  ('rootpage', None, None, None, None, None, None),
#  ('sql', None, None, None, None, None, None))

# %%
def get_header(cursor):
    '''
    Makes a tab delimited header row from the cursor description.
    Arguments:
        cursor: a cursor after a select query
    Returns:
        string: A string consisting of the column names separated by tabs, no new line
    '''
    return '\t'.join([row[0] for row in cursor.description])

# %%
def get_results(cursor):
    '''
    Makes a tab delimited table from the cursor results.
    Arguments:
        cursor: a cursor after a select query
    Returns:
        string: A string consisting of the column names separated by tabs, no new line
    ''' 
    res = list()
    for row in cursor.fetchall():        
        res.append('\t'.join(list(map(str,row))))
    return "\n".join(res)

# %%
# WHERE clause example (-- denotes comment)
# more examples later

sql = '''
SELECT *
FROM sqlite_master
WHERE type= "table"; -- condition that allows the selection of specific rows
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# type	name	tbl_name	rootpage	sql

# %%
sql='''
CREATE TABLE IF NOT EXISTS attributes (
    featureid CHAR(10),
    tag CHAR(10),
    value INTEGER,
    FOREIGN KEY(featureid) REFERENCES features(featureid)
    );
'''

try:
    cursor.execute(sql)
except connection.DatabaseError:
    print("Creating the table resulted in a database error!")
    connection.rollback()
    raise
else:
    connection.commit()
finally:
    print("done!")
# Out:
# done!

# %%
sql='''
CREATE TABLE IF NOT EXISTS features (
    featureid INTEGER PRIMARY KEY AUTOINCREMENT,
    seqid CHAR(10),
    source CHAR(10),
    type CHAR(10), 
    start INTEGER,
    end INTEGER,
    score INTEGER,
    strand CHAR(10),
    phase INTEGER,
    attributes CHAR(10)
    );
'''

try:
    cursor.execute(sql)
except connection.DatabaseError:
    print("Creating the table resulted in a database error!")
    connection.rollback()
    raise
else:
    connection.commit()
finally:
    print("done!")
# Out:
# done!

# %%
sql='''
DROP TABLE attribites;
'''
cursor.execute(sql)

# %%
data=pd.read_csv('Ecoli_ASM584v2_genomic.gff', sep='\t', names=['seqid', 'source', 'type', 'start', 'end', 'score', 'strand', 'phase', 'attributes'],comment='#')
data_features=data[['seqid','source','type','start','end','score','strand','phase']].values.tolist()
data_attributes=data['attributes'].str.split(';').tolist()
data_attributes
# Out:
# [['ID=NC_000913.3:1..4641652',
#   'Dbxref=taxon:511145',
#   'Is_circular=true',
#   'Name=ANONYMOUS',
#   'gbkey=Src',
#   'genome=chromosome',
#   'mol_type=genomic DNA',
#   'strain=K-12',
#   'substrain=MG1655'],
#  ['ID=gene-b0001',
#   'Dbxref=ASAP:ABE-0000006,ECOCYC:EG11277,EcoGene:EG11277,GeneID:944742',
#   'Name=thrL',
#   'gbkey=Gene',
#   'gene=thrL',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0001',
#   'locus_tag=b0001'],
#  ['ID=cds-NP_414542.1',
#   'Parent=gene-b0001',
#   'Dbxref=UniProtKB/Swiss-Prot:P0AD86,Genbank:NP_414542.1,ASAP:ABE-0000006,ECOCYC:EG11277,EcoGene:EG11277,GeneID:944742',
#   'Name=NP_414542.1',
#   'gbkey=CDS',
#   'gene=thrL',
#   'locus_tag=b0001',
#   'orig_transcript_id=gnl|b0001|mrna.b0001',
#   'product=thr operon leader peptide',
#   'protein_id=NP_414542.1',
#   'transl_table=11'],
#  ['ID=gene-b0002',
#   'Dbxref=ASAP:ABE-0000008,ECOCYC:EG10998,EcoGene:EG10998,GeneID:945803',
#   'Name=thrA',
#   'gbkey=Gene',
#   'gene=thrA',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0002,Hs,thrA1,thrA2,thrD',
#   'locus_tag=b0002'],
#  ['ID=cds-NP_414543.1',
#   'Parent=gene-b0002',
#   'Dbxref=UniProtKB/Swiss-Prot:P00561,Genbank:NP_414543.1,ASAP:ABE-0000008,ECOCYC:EG10998,EcoGene:EG10998,GeneID:945803',
#   'Name=NP_414543.1',
#   'gbkey=CDS',
#   'gene=thrA',
#   'locus_tag=b0002',
#   'orig_transcript_id=gnl|b0002|mrna.b0002',
#   'product=fused aspartate kinase/homoserine dehydrogenase 1',
#   'protein_id=NP_414543.1',
#   'transl_table=11'],
#  ['ID=gene-b0003',
#   'Dbxref=ASAP:ABE-0000010,ECOCYC:EG10999,EcoGene:EG10999,GeneID:947498',
#   'Name=thrB',
#   'gbkey=Gene',
#   'gene=thrB',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0003',
#   'locus_tag=b0003'],
#  ['ID=cds-NP_414544.1',
#   'Parent=gene-b0003',
#   'Dbxref=UniProtKB/Swiss-Prot:P00547,Genbank:NP_414544.1,ASAP:ABE-0000010,ECOCYC:EG10999,EcoGene:EG10999,GeneID:947498',
#   'Name=NP_414544.1',
#   'gbkey=CDS',
#   'gene=thrB',
#   'locus_tag=b0003',
#   'orig_transcript_id=gnl|b0003|mrna.b0003',
#   'product=homoserine kinase',
#   'protein_id=NP_414544.1',
#   'transl_table=11'],
#  ['ID=gene-b0004',
#   'Dbxref=ASAP:ABE-0000012,ECOCYC:EG11000,EcoGene:EG11000,GeneID:945198',
#   'Name=thrC',
#   'gbkey=Gene',
#   'gene=thrC',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0004',
#   'locus_tag=b0004'],
#  ['ID=cds-NP_414545.1',
#   'Parent=gene-b0004',
#   'Dbxref=UniProtKB/Swiss-Prot:P00934,Genbank:NP_414545.1,ASAP:ABE-0000012,ECOCYC:EG11000,EcoGene:EG11000,GeneID:945198',
#   'Name=NP_414545.1',
#   'gbkey=CDS',
#   'gene=thrC',
#   'locus_tag=b0004',
#   'orig_transcript_id=gnl|b0004|mrna.b0004',
#   'product=threonine synthase',
#   'protein_id=NP_414545.1',
#   'transl_table=11'],
#  ['ID=gene-b0005',
#   'Dbxref=ASAP:ABE-0000015,ECOCYC:G6081,EcoGene:EG14384,GeneID:944747',
#   'Name=yaaX',
#   'gbkey=Gene',
#   'gene=yaaX',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0005',
#   'locus_tag=b0005'],
#  ['ID=cds-NP_414546.1',
#   'Parent=gene-b0005',
#   'Dbxref=UniProtKB/Swiss-Prot:P75616,Genbank:NP_414546.1,ASAP:ABE-0000015,ECOCYC:G6081,EcoGene:EG14384,GeneID:944747',
#   'Name=NP_414546.1',
#   'gbkey=CDS',
#   'gene=yaaX',
#   'locus_tag=b0005',
#   'orig_transcript_id=gnl|b0005|mrna.b0005',
#   'product=DUF2502 domain-containing protein YaaX',
#   'protein_id=NP_414546.1',
#   'transl_table=11'],
#  ['ID=id-12', 'Note=REP1a', 'gbkey=repeat_region', 'rpt_type=other'],
#  ['ID=id-13', 'Note=REP1b', 'gbkey=repeat_region', 'rpt_type=other'],
#  ['ID=gene-b0006',
#   'Dbxref=ASAP:ABE-0000018,ECOCYC:EG10011,EcoGene:EG10011,GeneID:944749',
#   'Name=yaaA',
#   'gbkey=Gene',
#   'gene=yaaA',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0006',
#   'locus_tag=b0006'],
#  ['ID=cds-NP_414547.1',
#   'Parent=gene-b0006',
#   'Dbxref=UniProtKB/Swiss-Prot:P0A8I3,Genbank:NP_414547.1,ASAP:ABE-0000018,ECOCYC:EG10011,EcoGene:EG10011,GeneID:944749',
#   'Name=NP_414547.1',
#   'gbkey=CDS',
#   'gene=yaaA',
#   'locus_tag=b0006',
#   'orig_transcript_id=gnl|b0006|mrna.b0006',
#   'product=peroxide stress resistance protein YaaA',
#   'protein_id=NP_414547.1',
#   'transl_table=11'],
#  ['ID=gene-b0007',
#   'Dbxref=ASAP:ABE-0000020,ECOCYC:EG11555,EcoGene:EG11555,GeneID:944745',
#   'Name=yaaJ',
#   'gbkey=Gene',
#   'gene=yaaJ',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0007',
#   'locus_tag=b0007'],
#  ['ID=cds-NP_414548.1',
#   'Parent=gene-b0007',
#   'Dbxref=UniProtKB/Swiss-Prot:P30143,Genbank:NP_414548.1,ASAP:ABE-0000020,ECOCYC:EG11555,EcoGene:EG11555,GeneID:944745',
#   'Name=NP_414548.1',
#   'gbkey=CDS',
#   'gene=yaaJ',
#   'locus_tag=b0007',
#   'orig_transcript_id=gnl|b0007|mrna.b0007',
#   'product=putative transporter YaaJ',
#   'protein_id=NP_414548.1',
#   'transl_table=11'],
#  ['ID=gene-b0008',
#   'Dbxref=ASAP:ABE-0000027,ECOCYC:EG11556,EcoGene:EG11556,GeneID:944748',
#   'Name=talB',
#   'gbkey=Gene',
#   'gene=talB',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0008,yaaK',
#   'locus_tag=b0008'],
#  ['ID=cds-NP_414549.1',
#   'Parent=gene-b0008',
#   'Dbxref=UniProtKB/Swiss-Prot:P0A870,Genbank:NP_414549.1,ASAP:ABE-0000027,ECOCYC:EG11556,EcoGene:EG11556,GeneID:944748',
#   'Name=NP_414549.1',
#   'gbkey=CDS',
#   'gene=talB',
#   'locus_tag=b0008',
#   'orig_transcript_id=gnl|b0008|mrna.b0008',
#   'product=transaldolase B',
#   'protein_id=NP_414549.1',
#   'transl_table=11'],
#  ['ID=gene-b0009',
#   'Dbxref=ASAP:ABE-0000030,ECOCYC:EG11511,EcoGene:EG11511,GeneID:944760',
#   'Name=mog',
#   'gbkey=Gene',
#   'gene=mog',
#   'gene_biotype=protein_coding',
#   'gene_synonym=bisD,chlG,ECK0009,mogA,yaaG',
#   'locus_tag=b0009'],
#  ['ID=cds-NP_414550.1',
#   'Parent=gene-b0009',
#   'Dbxref=UniProtKB/Swiss-Prot:P0AF03,Genbank:NP_414550.1,ASAP:ABE-0000030,ECOCYC:EG11511,EcoGene:EG11511,GeneID:944760',
#   'Name=NP_414550.1',
#   'gbkey=CDS',
#   'gene=mog',
#   'locus_tag=b0009',
#   'orig_transcript_id=gnl|b0009|mrna.b0009',
#   'product=molybdopterin adenylyltransferase',
#   'protein_id=NP_414550.1',
#   'transl_table=11'],
#  ['ID=gene-b0010',
#   'Dbxref=ASAP:ABE-0000032,ECOCYC:EG11512,EcoGene:EG11512,GeneID:944792',
#   'Name=satP',
#   'gbkey=Gene',
#   'gene=satP',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0010,yaaH',
#   'locus_tag=b0010'],
#  ['ID=cds-NP_414551.1',
#   'Parent=gene-b0010',
#   'Dbxref=UniProtKB/Swiss-Prot:P0AC98,Genbank:NP_414551.1,ASAP:ABE-0000032,ECOCYC:EG11512,EcoGene:EG11512,GeneID:944792',
#   'Name=NP_414551.1',
#   'gbkey=CDS',
#   'gene=satP',
#   'locus_tag=b0010',
#   'orig_transcript_id=gnl|b0010|mrna.b0010',
#   'product=acetate/succinate:H(+) symporter',
#   'protein_id=NP_414551.1',
#   'transl_table=11'],
#  ['ID=gene-b0011',
#   'Dbxref=ASAP:ABE-0000037,ECOCYC:G6082,EcoGene:EG14340,GeneID:944771',
#   'Name=yaaW',
#   'gbkey=Gene',
#   'gene=yaaW',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0011',
#   'locus_tag=b0011'],
#  ['ID=cds-NP_414552.1',
#   'Parent=gene-b0011',
#   'Dbxref=UniProtKB/Swiss-Prot:P75617,Genbank:NP_414552.1,ASAP:ABE-0000037,ECOCYC:G6082,EcoGene:EG14340,GeneID:944771',
#   'Name=NP_414552.1',
#   'gbkey=CDS',
#   'gene=yaaW',
#   'locus_tag=b0011',
#   'orig_transcript_id=gnl|b0011|mrna.b0011',
#   'product=putative enzyme-specific chaperone YaaW',
#   'protein_id=NP_414552.1',
#   'transl_table=11'],
#  ['ID=gene-b0012',
#   'Dbxref=ASAP:ABE-0000040,ECOCYC:EG11509,EcoGene:EG11509,GeneID:948295',
#   'Name=mbiA',
#   'gbkey=Gene',
#   'gene=mbiA',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0012,htgA,htpY',
#   'locus_tag=b0012'],
#  ['ID=cds-YP_009518733.1',
#   'Parent=gene-b0012',
#   'Dbxref=UniProtKB/Swiss-Prot:P28697,Genbank:YP_009518733.1,ASAP:ABE-0000040,ECOCYC:EG11509,EcoGene:EG11509,GeneID:948295',
#   'Name=YP_009518733.1',
#   'gbkey=CDS',
#   'gene=mbiA',
#   'locus_tag=b0012',
#   'orig_transcript_id=gnl|b0012|mrna.CDS13',
#   'product=uncharacterized protein MbiA',
#   'protein_id=YP_009518733.1',
#   'transl_table=11'],
#  ['ID=gene-b0013',
#   'Dbxref=ASAP:ABE-0000043,ECOCYC:G8202,EcoGene:EG11513,GeneID:944751',
#   'Name=yaaI',
#   'gbkey=Gene',
#   'gene=yaaI',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0013',
#   'locus_tag=b0013'],
#  ['ID=cds-NP_414554.1',
#   'Parent=gene-b0013',
#   'Dbxref=UniProtKB/Swiss-Prot:P28696,Genbank:NP_414554.1,ASAP:ABE-0000043,ECOCYC:G8202,EcoGene:EG11513,GeneID:944751',
#   'Name=NP_414554.1',
#   'gbkey=CDS',
#   'gene=yaaI',
#   'locus_tag=b0013',
#   'orig_transcript_id=gnl|b0013|mrna.b0013',
#   'product=DUF2541 domain-containing protein YaaI',
#   'protein_id=NP_414554.1',
#   'transl_table=11'],
#  ['ID=gene-b0014',
#   'Dbxref=ASAP:ABE-0000052,ECOCYC:EG10241,EcoGene:EG10241,GeneID:944750',
#   'Name=dnaK',
#   'gbkey=Gene',
#   'gene=dnaK',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0014,groPAB,groPC,groPF,grpC,grpF,seg',
#   'locus_tag=b0014'],
#  ['ID=cds-NP_414555.1',
#   'Parent=gene-b0014',
#   'Dbxref=UniProtKB/Swiss-Prot:P0A6Y8,Genbank:NP_414555.1,ASAP:ABE-0000052,ECOCYC:EG10241,EcoGene:EG10241,GeneID:944750',
#   'Name=NP_414555.1',
#   'gbkey=CDS',
#   'gene=dnaK',
#   'locus_tag=b0014',
#   'orig_transcript_id=gnl|b0014|mrna.b0014',
#   'product=chaperone protein DnaK',
#   'protein_id=NP_414555.1',
#   'transl_table=11'],
#  ['ID=gene-b0015',
#   'Dbxref=ASAP:ABE-0000054,ECOCYC:EG10240,EcoGene:EG10240,GeneID:944753',
#   'Name=dnaJ',
#   'gbkey=Gene',
#   'gene=dnaJ',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0015,groP,grpC',
#   'locus_tag=b0015'],
#  ['ID=cds-NP_414556.1',
#   'Parent=gene-b0015',
#   'Dbxref=UniProtKB/Swiss-Prot:P08622,Genbank:NP_414556.1,ASAP:ABE-0000054,ECOCYC:EG10240,EcoGene:EG10240,GeneID:944753',
#   'Name=NP_414556.1',
#   'gbkey=CDS',
#   'gene=dnaJ',
#   'locus_tag=b0015',
#   'orig_transcript_id=gnl|b0015|mrna.b0015',
#   'product=chaperone protein DnaJ',
#   'protein_id=NP_414556.1',
#   'transl_table=11'],
#  ['ID=id-34',
#   'gbkey=mobile_element',
#   'mobile_element_type=insertion sequence:IS186A'],
#  ['ID=gene-b0016',
#   'Dbxref=ASAP:ABE-0000058,ECOCYC:G6083,EcoGene:EG60001,GeneID:944754',
#   'Name=insL-1',
#   'gbkey=Gene',
#   'gene=insL-1',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0016,yi81-1',
#   'locus_tag=b0016'],
#  ['ID=cds-NP_414557.1',
#   'Parent=gene-b0016',
#   'Dbxref=UniProtKB/Swiss-Prot:P0CF91,Genbank:NP_414557.1,ASAP:ABE-0000058,ECOCYC:G6083,EcoGene:EG60001,GeneID:944754',
#   'Name=NP_414557.1',
#   'gbkey=CDS',
#   'gene=insL-1',
#   'locus_tag=b0016',
#   'orig_transcript_id=gnl|b0016|mrna.b0016',
#   'product=IS186/IS421 transposase',
#   'protein_id=NP_414557.1',
#   'transl_table=11'],
#  ['ID=gene-b0018',
#   'Dbxref=ASAP:ABE-0000064,ECOCYC:EG10373,EcoGene:EG12074,GeneID:944756',
#   'Name=mokC',
#   'gbkey=Gene',
#   'gene=mokC',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0018,gefL',
#   'locus_tag=b0018'],
#  ['ID=cds-NP_414559.1',
#   'Parent=gene-b0018',
#   'Dbxref=UniProtKB/Swiss-Prot:P33236,Genbank:NP_414559.1,ASAP:ABE-0000064,ECOCYC:EG10373,EcoGene:EG12074,GeneID:944756',
#   'Name=NP_414559.1',
#   'gbkey=CDS',
#   'gene=mokC',
#   'locus_tag=b0018',
#   'orig_transcript_id=gnl|b0018|mrna.b0018',
#   'product=regulatory protein MokC',
#   'protein_id=NP_414559.1',
#   'transl_table=11'],
#  ['ID=gene-b4412',
#   'Dbxref=ASAP:ABE-0047278,ECOCYC:G0-9563,EcoGene:EG10373,GeneID:2847744',
#   'Name=hokC',
#   'gbkey=Gene',
#   'gene=hokC',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0017,gef',
#   'locus_tag=b4412'],
#  ['ID=cds-YP_025292.1',
#   'Parent=gene-b4412',
#   'Dbxref=UniProtKB/Swiss-Prot:P0ACG4,Genbank:YP_025292.1,ASAP:ABE-0047278,ECOCYC:G0-9563,EcoGene:EG10373,GeneID:2847744',
#   'Name=YP_025292.1',
#   'gbkey=CDS',
#   'gene=hokC',
#   'locus_tag=b4412',
#   'orig_transcript_id=gnl|b4412|mrna.b4412',
#   'product=protein HokC',
#   'protein_id=YP_025292.1',
#   'transl_table=11'],
#  ['ID=gene-b4413',
#   'Dbxref=ASAP:ABE-0047238,ECOCYC:G0-9581,EcoGene:EG31128,GeneID:2847745',
#   'Name=sokC',
#   'gbkey=Gene',
#   'gene=sokC',
#   'gene_biotype=ncRNA',
#   'gene_synonym=ECK0019,sof',
#   'locus_tag=b4413'],
#  ['ID=rna-b4413',
#   'Parent=gene-b4413',
#   'Dbxref=ASAP:ABE-0047238,ECOCYC:G0-9581,EcoGene:EG31128,GeneID:2847745',
#   'gbkey=ncRNA',
#   'gene=sokC',
#   'locus_tag=b4413',
#   'product=antisense RNA blocking mokC and hokC translation'],
#  ['ID=exon-b4413-1',
#   'Parent=rna-b4413',
#   'Dbxref=ASAP:ABE-0047238,ECOCYC:G0-9581,EcoGene:EG31128,GeneID:2847745',
#   'gbkey=ncRNA',
#   'gene=sokC',
#   'locus_tag=b4413',
#   'product=antisense RNA blocking mokC and hokC translation'],
#  ['ID=gene-b0019',
#   'Dbxref=ASAP:ABE-0000068,ECOCYC:EG10652,EcoGene:EG10652,GeneID:944758',
#   'Name=nhaA',
#   'gbkey=Gene',
#   'gene=nhaA',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ant,antA,ECK0020,hyc',
#   'locus_tag=b0019'],
#  ['ID=cds-NP_414560.1',
#   'Parent=gene-b0019',
#   'Dbxref=UniProtKB/Swiss-Prot:P13738,Genbank:NP_414560.1,ASAP:ABE-0000068,ECOCYC:EG10652,EcoGene:EG10652,GeneID:944758',
#   'Name=NP_414560.1',
#   'gbkey=CDS',
#   'gene=nhaA',
#   'locus_tag=b0019',
#   'orig_transcript_id=gnl|b0019|mrna.b0019',
#   'product=Na(+):H(+) antiporter NhaA',
#   'protein_id=NP_414560.1',
#   'transl_table=11'],
#  ['ID=gene-b0020',
#   'Dbxref=ASAP:ABE-0000072,ECOCYC:EG11078,EcoGene:EG11078,GeneID:944757',
#   'Name=nhaR',
#   'gbkey=Gene',
#   'gene=nhaR',
#   'gene_biotype=protein_coding',
#   'gene_synonym=antO,ECK0021,yaaB',
#   'locus_tag=b0020'],
#  ['ID=cds-NP_414561.1',
#   'Parent=gene-b0020',
#   'Dbxref=UniProtKB/Swiss-Prot:P0A9G2,Genbank:NP_414561.1,ASAP:ABE-0000072,ECOCYC:EG11078,EcoGene:EG11078,GeneID:944757',
#   'Name=NP_414561.1',
#   'gbkey=CDS',
#   'gene=nhaR',
#   'locus_tag=b0020',
#   'orig_transcript_id=gnl|b0020|mrna.b0020',
#   'product=DNA-binding transcriptional activator NhaR',
#   'protein_id=NP_414561.1',
#   'transl_table=11'],
#  ['ID=id-47',
#   'gbkey=mobile_element',
#   'mobile_element_type=insertion sequence:IS1A'],
#  ['ID=gene-b0021',
#   'Dbxref=ASAP:ABE-0000075,ECOCYC:G6085,EcoGene:EG60002,GeneID:944743',
#   'Name=insB-1',
#   'gbkey=Gene',
#   'gene=insB-1',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0022',
#   'locus_tag=b0021'],
#  ['ID=cds-NP_414562.1',
#   'Parent=gene-b0021',
#   'Dbxref=UniProtKB/Swiss-Prot:P0CF25,Genbank:NP_414562.1,ASAP:ABE-0000075,ECOCYC:G6085,EcoGene:EG60002,GeneID:944743',
#   'Name=NP_414562.1',
#   'gbkey=CDS',
#   'gene=insB-1',
#   'locus_tag=b0021',
#   'orig_transcript_id=gnl|b0021|mrna.b0021',
#   'product=IS1 protein InsB',
#   'protein_id=NP_414562.1',
#   'transl_table=11'],
#  ['ID=gene-b0022',
#   'Dbxref=ASAP:ABE-0000078,ECOCYC:G6086,EcoGene:EG40001,GeneID:948449',
#   'Name=insA-1',
#   'gbkey=Gene',
#   'gene=insA-1',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0023',
#   'locus_tag=b0022'],
#  ['ID=cds-NP_414563.1',
#   'Parent=gene-b0022',
#   'Dbxref=UniProtKB/Swiss-Prot:P0CF07,Genbank:NP_414563.1,ASAP:ABE-0000078,ECOCYC:G6086,EcoGene:EG40001,GeneID:948449',
#   'Name=NP_414563.1',
#   'gbkey=CDS',
#   'gene=insA-1',
#   'locus_tag=b0022',
#   'orig_transcript_id=gnl|b0022|mrna.b0022',
#   'product=IS1 protein InsA',
#   'protein_id=NP_414563.1',
#   'transl_table=11'],
#  ['ID=gene-b0023',
#   'Dbxref=ASAP:ABE-0000082,ECOCYC:EG10919,EcoGene:EG10919,GeneID:944759',
#   'Name=rpsT',
#   'gbkey=Gene',
#   'gene=rpsT',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0024,sup(s20),supS,supS20',
#   'locus_tag=b0023'],
#  ['ID=cds-NP_414564.1',
#   'Parent=gene-b0023',
#   'Dbxref=UniProtKB/Swiss-Prot:P0A7U7,Genbank:NP_414564.1,ASAP:ABE-0000082,ECOCYC:EG10919,EcoGene:EG10919,GeneID:944759',
#   'Name=NP_414564.1',
#   'gbkey=CDS',
#   'gene=rpsT',
#   'locus_tag=b0023',
#   'orig_transcript_id=gnl|b0023|mrna.b0023',
#   'product=30S ribosomal subunit protein S20',
#   'protein_id=NP_414564.1',
#   'transl_table=11'],
#  ['ID=gene-b0024',
#   'Dbxref=ASAP:ABE-0000089,ECOCYC:G6087,EcoGene:EG14386,GeneID:949128',
#   'Name=yaaY',
#   'gbkey=Gene',
#   'gene=yaaY',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0025',
#   'locus_tag=b0024'],
#  ['ID=cds-NP_414565.1',
#   'Parent=gene-b0024',
#   'Dbxref=UniProtKB/Swiss-Prot:P75620,Genbank:NP_414565.1,ASAP:ABE-0000089,ECOCYC:G6087,EcoGene:EG14386,GeneID:949128',
#   'Name=NP_414565.1',
#   'gbkey=CDS',
#   'gene=yaaY',
#   'locus_tag=b0024',
#   'orig_transcript_id=gnl|b0024|mrna.b0024',
#   'product=DUF2575 domain-containing protein YaaY',
#   'protein_id=NP_414565.1',
#   'transl_table=11'],
#  ['ID=gene-b0025',
#   'Dbxref=ASAP:ABE-0000091,ECOCYC:EG11079,EcoGene:EG11079,GeneID:949129',
#   'Name=ribF',
#   'gbkey=Gene',
#   'gene=ribF',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0026,yaaC',
#   'locus_tag=b0025'],
#  ['ID=cds-NP_414566.1',
#   'Parent=gene-b0025',
#   'Dbxref=UniProtKB/Swiss-Prot:P0AG40,Genbank:NP_414566.1,ASAP:ABE-0000091,ECOCYC:EG11079,EcoGene:EG11079,GeneID:949129',
#   'Name=NP_414566.1',
#   'gbkey=CDS',
#   'gene=ribF',
#   'locus_tag=b0025',
#   'orig_transcript_id=gnl|b0025|mrna.b0025',
#   'product=bifunctional riboflavin kinase/FMN adenylyltransferase',
#   'protein_id=NP_414566.1',
#   'transl_table=11'],
#  ['ID=gene-b0026',
#   'Dbxref=ASAP:ABE-0000094,ECOCYC:EG10492,EcoGene:EG10492,GeneID:944761',
#   'Name=ileS',
#   'gbkey=Gene',
#   'gene=ileS',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0027,ilvS',
#   'locus_tag=b0026'],
#  ['ID=cds-NP_414567.1',
#   'Parent=gene-b0026',
#   'Dbxref=UniProtKB/Swiss-Prot:P00956,Genbank:NP_414567.1,ASAP:ABE-0000094,ECOCYC:EG10492,EcoGene:EG10492,GeneID:944761',
#   'Name=NP_414567.1',
#   'gbkey=CDS',
#   'gene=ileS',
#   'locus_tag=b0026',
#   'orig_transcript_id=gnl|b0026|mrna.b0026',
#   'product=isoleucine--tRNA ligase',
#   'protein_id=NP_414567.1',
#   'transl_table=11'],
#  ['ID=gene-b0027',
#   'Dbxref=ASAP:ABE-0000096,ECOCYC:EG10548,EcoGene:EG10548,GeneID:944800',
#   'Name=lspA',
#   'gbkey=Gene',
#   'gene=lspA',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0028,lsp',
#   'locus_tag=b0027'],
#  ['ID=cds-NP_414568.1',
#   'Parent=gene-b0027',
#   'Dbxref=UniProtKB/Swiss-Prot:P00804,Genbank:NP_414568.1,ASAP:ABE-0000096,ECOCYC:EG10548,EcoGene:EG10548,GeneID:944800',
#   'Name=NP_414568.1',
#   'gbkey=CDS',
#   'gene=lspA',
#   'locus_tag=b0027',
#   'orig_transcript_id=gnl|b0027|mrna.b0027',
#   'product=lipoprotein signal peptidase',
#   'protein_id=NP_414568.1',
#   'transl_table=11'],
#  ['ID=id-62', 'Note=REP2a', 'gbkey=repeat_region', 'rpt_type=other'],
#  ['ID=id-63', 'Note=REP2b', 'gbkey=repeat_region', 'rpt_type=other'],
#  ['ID=gene-b0028',
#   'Dbxref=ASAP:ABE-0000101,ECOCYC:EG11080,EcoGene:EG11080,GeneID:944807',
#   'Name=fkpB',
#   'gbkey=Gene',
#   'gene=fkpB',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0029,slpA,yaaD',
#   'locus_tag=b0028'],
#  ['ID=cds-NP_414569.1',
#   'Parent=gene-b0028',
#   'Dbxref=UniProtKB/Swiss-Prot:P0AEM0,Genbank:NP_414569.1,ASAP:ABE-0000101,ECOCYC:EG11080,EcoGene:EG11080,GeneID:944807',
#   'Name=NP_414569.1',
#   'gbkey=CDS',
#   'gene=fkpB',
#   'locus_tag=b0028',
#   'orig_transcript_id=gnl|b0028|mrna.b0028',
#   'product=peptidyl-prolyl cis-trans isomerase FkpB',
#   'protein_id=NP_414569.1',
#   'transl_table=11'],
#  ['ID=gene-b0029',
#   'Dbxref=ASAP:ABE-0000103,ECOCYC:EG11081,EcoGene:EG11081,GeneID:944777',
#   'Name=ispH',
#   'gbkey=Gene',
#   'gene=ispH',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0030,lytB,yaaE',
#   'locus_tag=b0029'],
#  ['ID=cds-NP_414570.1',
#   'Parent=gene-b0029',
#   'Dbxref=UniProtKB/Swiss-Prot:P62623,Genbank:NP_414570.1,ASAP:ABE-0000103,ECOCYC:EG11081,EcoGene:EG11081,GeneID:944777',
#   'Name=NP_414570.1',
#   'gbkey=CDS',
#   'gene=ispH',
#   'locus_tag=b0029',
#   'orig_transcript_id=gnl|b0029|mrna.b0029',
#   'product=1-hydroxy-2-methyl-2-(E)-butenyl 4-diphosphate reductase',
#   'protein_id=NP_414570.1',
#   'transl_table=11'],
#  ['ID=gene-b0030',
#   'Dbxref=ASAP:ABE-0000109,ECOCYC:EG11082,EcoGene:EG11082,GeneID:944796',
#   'Name=rihC',
#   'gbkey=Gene',
#   'gene=rihC',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0031,yaaF',
#   'locus_tag=b0030'],
#  ['ID=cds-NP_414571.1',
#   'Parent=gene-b0030',
#   'Dbxref=UniProtKB/Swiss-Prot:P22564,Genbank:NP_414571.1,ASAP:ABE-0000109,ECOCYC:EG11082,EcoGene:EG11082,GeneID:944796',
#   'Name=NP_414571.1',
#   'gbkey=CDS',
#   'gene=rihC',
#   'locus_tag=b0030',
#   'orig_transcript_id=gnl|b0030|mrna.b0030',
#   'product=ribonucleoside hydrolase RihC',
#   'protein_id=NP_414571.1',
#   'transl_table=11'],
#  ['ID=gene-b0031',
#   'Dbxref=ASAP:ABE-0000112,ECOCYC:EG10206,EcoGene:EG10206,GeneID:944762',
#   'Name=dapB',
#   'gbkey=Gene',
#   'gene=dapB',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0032',
#   'locus_tag=b0031'],
#  ['ID=cds-NP_414572.1',
#   'Parent=gene-b0031',
#   'Dbxref=UniProtKB/Swiss-Prot:P04036,Genbank:NP_414572.1,ASAP:ABE-0000112,ECOCYC:EG10206,EcoGene:EG10206,GeneID:944762',
#   'Name=NP_414572.1',
#   'gbkey=CDS',
#   'gene=dapB',
#   'locus_tag=b0031',
#   'orig_transcript_id=gnl|b0031|mrna.b0031',
#   'product=4-hydroxy-tetrahydrodipicolinate reductase',
#   'protein_id=NP_414572.1',
#   'transl_table=11'],
#  ['ID=gene-b0032',
#   'Dbxref=ASAP:ABE-0000118,ECOCYC:EG10134,EcoGene:EG10134,GeneID:949025',
#   'Name=carA',
#   'gbkey=Gene',
#   'gene=carA',
#   'gene_biotype=protein_coding',
#   'gene_synonym=arg,cap,ECK0033,pyrA',
#   'locus_tag=b0032'],
#  ['ID=cds-NP_414573.1',
#   'Parent=gene-b0032',
#   'Dbxref=UniProtKB/Swiss-Prot:P0A6F1,Genbank:NP_414573.1,ASAP:ABE-0000118,ECOCYC:EG10134,EcoGene:EG10134,GeneID:949025',
#   'Name=NP_414573.1',
#   'gbkey=CDS',
#   'gene=carA',
#   'locus_tag=b0032',
#   'orig_transcript_id=gnl|b0032|mrna.b0032',
#   'product=carbamoyl phosphate synthetase subunit alpha',
#   'protein_id=NP_414573.1',
#   'transl_table=11'],
#  ['ID=gene-b0033',
#   'Dbxref=ASAP:ABE-0000121,ECOCYC:EG10135,EcoGene:EG10135,GeneID:944775',
#   'Name=carB',
#   'gbkey=Gene',
#   'gene=carB',
#   'gene_biotype=protein_coding',
#   'gene_synonym=cap,ECK0034,pyrA',
#   'locus_tag=b0033'],
#  ['ID=cds-NP_414574.1',
#   'Parent=gene-b0033',
#   'Dbxref=UniProtKB/Swiss-Prot:P00968,Genbank:NP_414574.1,ASAP:ABE-0000121,ECOCYC:EG10135,EcoGene:EG10135,GeneID:944775',
#   'Name=NP_414574.1',
#   'gbkey=CDS',
#   'gene=carB',
#   'locus_tag=b0033',
#   'orig_transcript_id=gnl|b0033|mrna.b0033',
#   'product=carbamoyl phosphate synthetase subunit beta',
#   'protein_id=NP_414574.1',
#   'transl_table=11'],
#  ['ID=gene-b0034',
#   'Dbxref=ASAP:ABE-0000125,ECOCYC:G6088,EcoGene:EG13451,GeneID:944795',
#   'Name=caiF',
#   'gbkey=Gene',
#   'gene=caiF',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0035',
#   'locus_tag=b0034'],
#  ['ID=cds-NP_414576.4',
#   'Parent=gene-b0034',
#   'Dbxref=UniProtKB/Swiss-Prot:P0AE58,Genbank:NP_414576.4,ASAP:ABE-0000125,ECOCYC:G6088,EcoGene:EG13451,GeneID:944795',
#   'Name=NP_414576.4',
#   'gbkey=CDS',
#   'gene=caiF',
#   'locus_tag=b0034',
#   'orig_transcript_id=gnl|b0034|mrna.b0034',
#   'product=DNA-binding transcriptional activator CaiF',
#   'protein_id=NP_414576.4',
#   'transl_table=11'],
#  ['ID=id-78', 'Note=REP3', 'gbkey=repeat_region', 'rpt_type=other'],
#  ['ID=gene-b0035',
#   'Dbxref=ASAP:ABE-0000128,ECOCYC:EG12608,EcoGene:EG12608,GeneID:948999',
#   'Name=caiE',
#   'gbkey=Gene',
#   'gene=caiE',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0036',
#   'locus_tag=b0035'],
#  ['ID=cds-NP_414577.2',
#   'Parent=gene-b0035',
#   'Dbxref=UniProtKB/Swiss-Prot:P39206,Genbank:NP_414577.2,ASAP:ABE-0000128,ECOCYC:EG12608,EcoGene:EG12608,GeneID:948999',
#   'Name=NP_414577.2',
#   'gbkey=CDS',
#   'gene=caiE',
#   'locus_tag=b0035',
#   'orig_transcript_id=gnl|b0035|mrna.b0035',
#   'product=putative transferase CaiE',
#   'protein_id=NP_414577.2',
#   'transl_table=11'],
#  ['ID=gene-b0036',
#   'Dbxref=ASAP:ABE-0000130,ECOCYC:EG11557,EcoGene:EG11557,GeneID:948995',
#   'Name=caiD',
#   'gbkey=Gene',
#   'gene=caiD',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0037,yaaL',
#   'locus_tag=b0036'],
#  ['ID=cds-NP_414578.2',
#   'Parent=gene-b0036',
#   'Dbxref=UniProtKB/Swiss-Prot:P31551,Genbank:NP_414578.2,ASAP:ABE-0000130,ECOCYC:EG11557,EcoGene:EG11557,GeneID:948995',
#   'Name=NP_414578.2',
#   'gbkey=CDS',
#   'gene=caiD',
#   'locus_tag=b0036',
#   'orig_transcript_id=gnl|b0036|mrna.b0036',
#   'product=crotonobetainyl-CoA hydratase',
#   'protein_id=NP_414578.2',
#   'transl_table=11'],
#  ['ID=gene-b0037',
#   'Dbxref=ASAP:ABE-0000133,ECOCYC:EG11558,EcoGene:EG11558,GeneID:944886',
#   'Name=caiC',
#   'gbkey=Gene',
#   'gene=caiC',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0038,yaaM',
#   'locus_tag=b0037'],
#  ['ID=cds-NP_414579.4',
#   'Parent=gene-b0037',
#   'Dbxref=UniProtKB/Swiss-Prot:P31552,Genbank:NP_414579.4,ASAP:ABE-0000133,ECOCYC:EG11558,EcoGene:EG11558,GeneID:944886',
#   'Name=NP_414579.4',
#   'gbkey=CDS',
#   'gene=caiC',
#   'locus_tag=b0037',
#   'orig_transcript_id=gnl|b0037|mrna.b0037',
#   'product=carnitine-CoA ligase',
#   'protein_id=NP_414579.4',
#   'transl_table=11'],
#  ['ID=gene-b0038',
#   'Dbxref=ASAP:ABE-0000136,ECOCYC:EG11559,EcoGene:EG11559,GeneID:948997',
#   'Name=caiB',
#   'gbkey=Gene',
#   'gene=caiB',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0039,yaaN',
#   'locus_tag=b0038'],
#  ['ID=cds-NP_414580.1',
#   'Parent=gene-b0038',
#   'Dbxref=UniProtKB/Swiss-Prot:P31572,Genbank:NP_414580.1,ASAP:ABE-0000136,ECOCYC:EG11559,EcoGene:EG11559,GeneID:948997',
#   'Name=NP_414580.1',
#   'gbkey=CDS',
#   'gene=caiB',
#   'locus_tag=b0038',
#   'orig_transcript_id=gnl|b0038|mrna.b0038',
#   'product=gamma-butyrobetainyl-CoA:carnitine CoA transferase',
#   'protein_id=NP_414580.1',
#   'transl_table=11'],
#  ['ID=id-87', 'Note=REP4a', 'gbkey=repeat_region', 'rpt_type=other'],
#  ['ID=id-88', 'Note=REP4b', 'gbkey=repeat_region', 'rpt_type=other'],
#  ['ID=gene-b0039',
#   'Dbxref=ASAP:ABE-0000139,ECOCYC:EG11560,EcoGene:EG11560,GeneID:949064',
#   'Name=caiA',
#   'gbkey=Gene',
#   'gene=caiA',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0040,yaaO',
#   'locus_tag=b0039'],
#  ['ID=cds-NP_414581.1',
#   'Parent=gene-b0039',
#   'Dbxref=UniProtKB/Swiss-Prot:P60584,Genbank:NP_414581.1,ASAP:ABE-0000139,ECOCYC:EG11560,EcoGene:EG11560,GeneID:949064',
#   'Name=NP_414581.1',
#   'gbkey=CDS',
#   'gene=caiA',
#   'locus_tag=b0039',
#   'orig_transcript_id=gnl|b0039|mrna.b0039',
#   'product=crotonobetainyl-CoA reductase',
#   'protein_id=NP_414581.1',
#   'transl_table=11'],
#  ['ID=gene-b0040',
#   'Dbxref=ASAP:ABE-0000141,ECOCYC:EG11561,EcoGene:EG11561,GeneID:944765',
#   'Name=caiT',
#   'gbkey=Gene',
#   'gene=caiT',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0041,yaaP',
#   'locus_tag=b0040'],
#  ['ID=cds-NP_414582.1',
#   'Parent=gene-b0040',
#   'Dbxref=UniProtKB/Swiss-Prot:P31553,Genbank:NP_414582.1,ASAP:ABE-0000141,ECOCYC:EG11561,EcoGene:EG11561,GeneID:944765',
#   'Name=NP_414582.1',
#   'gbkey=CDS',
#   'gene=caiT',
#   'locus_tag=b0040',
#   'orig_transcript_id=gnl|b0040|mrna.b0040',
#   'product=L-carnitine:gamma-butyrobetaine antiporter',
#   'protein_id=NP_414582.1',
#   'transl_table=11'],
#  ['ID=gene-b0041',
#   'Dbxref=ASAP:ABE-0000145,ECOCYC:EG11562,EcoGene:EG11562,GeneID:947316',
#   'Name=fixA',
#   'gbkey=Gene',
#   'gene=fixA',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0042,yaaQ',
#   'locus_tag=b0041'],
#  ['ID=cds-NP_414583.2',
#   'Parent=gene-b0041',
#   'Dbxref=UniProtKB/Swiss-Prot:P60566,Genbank:NP_414583.2,ASAP:ABE-0000145,ECOCYC:EG11562,EcoGene:EG11562,GeneID:947316',
#   'Name=NP_414583.2',
#   'gbkey=CDS',
#   'gene=fixA',
#   'locus_tag=b0041',
#   'orig_transcript_id=gnl|b0041|mrna.b0041',
#   'product=putative electron transfer flavoprotein FixA',
#   'protein_id=NP_414583.2',
#   'transl_table=11'],
#  ['ID=gene-b0042',
#   'Dbxref=ASAP:ABE-0000147,ECOCYC:EG11563,EcoGene:EG11563,GeneID:948939',
#   'Name=fixB',
#   'gbkey=Gene',
#   'gene=fixB',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0043,yaaR',
#   'locus_tag=b0042'],
#  ['ID=cds-NP_414584.1',
#   'Parent=gene-b0042',
#   'Dbxref=UniProtKB/Swiss-Prot:P31574,Genbank:NP_414584.1,ASAP:ABE-0000147,ECOCYC:EG11563,EcoGene:EG11563,GeneID:948939',
#   'Name=NP_414584.1',
#   'gbkey=CDS',
#   'gene=fixB',
#   'locus_tag=b0042',
#   'orig_transcript_id=gnl|b0042|mrna.b0042',
#   'product=putative electron transfer flavoprotein FixB',
#   'protein_id=NP_414584.1',
#   'transl_table=11'],
#  ['ID=gene-b0043',
#   'Dbxref=ASAP:ABE-0000149,ECOCYC:EG11564,EcoGene:EG11564,GeneID:948958',
#   'Name=fixC',
#   'gbkey=Gene',
#   'gene=fixC',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0044,yaaS',
#   'locus_tag=b0043'],
#  ['ID=cds-NP_414585.1',
#   'Parent=gene-b0043',
#   'Dbxref=UniProtKB/Swiss-Prot:P68644,Genbank:NP_414585.1,ASAP:ABE-0000149,ECOCYC:EG11564,EcoGene:EG11564,GeneID:948958',
#   'Name=NP_414585.1',
#   'gbkey=CDS',
#   'gene=fixC',
#   'locus_tag=b0043',
#   'orig_transcript_id=gnl|b0043|mrna.b0043',
#   'product=putative oxidoreductase FixC',
#   'protein_id=NP_414585.1',
#   'transl_table=11'],
#  ['ID=gene-b0044',
#   'Dbxref=ASAP:ABE-0000151,ECOCYC:EG11565,EcoGene:EG11565,GeneID:948590',
#   'Name=fixX',
#   'gbkey=Gene',
#   'gene=fixX',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0045,yaaT',
#   'locus_tag=b0044'],
#  ['ID=cds-NP_414586.1',
#   'Parent=gene-b0044',
#   'Dbxref=UniProtKB/Swiss-Prot:P68646,Genbank:NP_414586.1,ASAP:ABE-0000151,ECOCYC:EG11565,EcoGene:EG11565,GeneID:948590',
#   'Name=NP_414586.1',
#   'gbkey=CDS',
#   'gene=fixX',
#   'locus_tag=b0044',
#   'orig_transcript_id=gnl|b0044|mrna.b0044',
#   'product=putative ferredoxin FixX',
#   'protein_id=NP_414586.1',
#   'transl_table=11'],
#  ['ID=gene-b0045',
#   'Dbxref=ASAP:ABE-0000156,ECOCYC:EG11566,EcoGene:EG11566,GeneID:944766',
#   'Name=yaaU',
#   'gbkey=Gene',
#   'gene=yaaU',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0046,yabE',
#   'locus_tag=b0045'],
#  ['ID=cds-NP_414587.1',
#   'Parent=gene-b0045',
#   'Dbxref=UniProtKB/Swiss-Prot:P31679,Genbank:NP_414587.1,ASAP:ABE-0000156,ECOCYC:EG11566,EcoGene:EG11566,GeneID:944766',
#   'Name=NP_414587.1',
#   'gbkey=CDS',
#   'gene=yaaU',
#   'locus_tag=b0045',
#   'orig_transcript_id=gnl|b0045|mrna.b0045',
#   'product=putative transporter YaaU',
#   'protein_id=NP_414587.1',
#   'transl_table=11'],
#  ['ID=gene-b0046',
#   'Dbxref=ASAP:ABE-0000159,ECOCYC:EG11568,EcoGene:EG11568,GeneID:944767',
#   'Name=kefF',
#   'gbkey=Gene',
#   'gene=kefF',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0047,yabF',
#   'locus_tag=b0046'],
#  ['ID=cds-NP_414588.1',
#   'Parent=gene-b0046',
#   'Dbxref=UniProtKB/Swiss-Prot:P0A754,Genbank:NP_414588.1,ASAP:ABE-0000159,ECOCYC:EG11568,EcoGene:EG11568,GeneID:944767',
#   'Name=NP_414588.1',
#   'gbkey=CDS',
#   'gene=kefF',
#   'locus_tag=b0046',
#   'orig_transcript_id=gnl|b0046|mrna.b0046',
#   'product=regulator of KefC-mediated potassium transport and quinone oxidoreductase',
#   'protein_id=NP_414588.1',
#   'transl_table=11'],
#  ['ID=gene-b0047',
#   'Dbxref=ASAP:ABE-0000161,ECOCYC:EG10521,EcoGene:EG10521,GeneID:944773',
#   'Name=kefC',
#   'gbkey=Gene',
#   'gene=kefC',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0048,trkC',
#   'locus_tag=b0047'],
#  ['ID=cds-NP_414589.1',
#   'Parent=gene-b0047',
#   'Dbxref=UniProtKB/Swiss-Prot:P03819,Genbank:NP_414589.1,ASAP:ABE-0000161,ECOCYC:EG10521,EcoGene:EG10521,GeneID:944773',
#   'Name=NP_414589.1',
#   'gbkey=CDS',
#   'gene=kefC',
#   'locus_tag=b0047',
#   'orig_transcript_id=gnl|b0047|mrna.b0047',
#   'product=K(+) : H(+) antiporter KefC',
#   'protein_id=NP_414589.1',
#   'transl_table=11'],
#  ['ID=gene-b0048',
#   'Dbxref=ASAP:ABE-0000164,ECOCYC:EG10326,EcoGene:EG10326,GeneID:944790',
#   'Name=folA',
#   'gbkey=Gene',
#   'gene=folA',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0049,tmr,tmrA',
#   'locus_tag=b0048'],
#  ['ID=cds-NP_414590.1',
#   'Parent=gene-b0048',
#   'Dbxref=UniProtKB/Swiss-Prot:P0ABQ4,Genbank:NP_414590.1,ASAP:ABE-0000164,ECOCYC:EG10326,EcoGene:EG10326,GeneID:944790',
#   'Name=NP_414590.1',
#   'gbkey=CDS',
#   'gene=folA',
#   'locus_tag=b0048',
#   'orig_transcript_id=gnl|b0048|mrna.b0048',
#   'product=dihydrofolate reductase',
#   'protein_id=NP_414590.1',
#   'transl_table=11'],
#  ['ID=id-109', 'Note=REP5', 'gbkey=repeat_region', 'rpt_type=other'],
#  ['ID=gene-b0049',
#   'Dbxref=ASAP:ABE-0000167,ECOCYC:EG10048,EcoGene:EG10048,GeneID:944770',
#   'Name=apaH',
#   'gbkey=Gene',
#   'gene=apaH',
#   'gene_biotype=protein_coding',
#   'gene_synonym=cfcB,ECK0050',
#   'locus_tag=b0049'],
#  ['ID=cds-NP_414591.1',
#   'Parent=gene-b0049',
#   'Dbxref=UniProtKB/Swiss-Prot:P05637,Genbank:NP_414591.1,ASAP:ABE-0000167,ECOCYC:EG10048,EcoGene:EG10048,GeneID:944770',
#   'Name=NP_414591.1',
#   'gbkey=CDS',
#   'gene=apaH',
#   'locus_tag=b0049',
#   'orig_transcript_id=gnl|b0049|mrna.b0049',
#   'product=diadenosine tetraphosphatase',
#   'protein_id=NP_414591.1',
#   'transl_table=11'],
#  ['ID=gene-b0050',
#   'Dbxref=ASAP:ABE-0000169,ECOCYC:EG10047,EcoGene:EG10047,GeneID:944772',
#   'Name=apaG',
#   'gbkey=Gene',
#   'gene=apaG',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0051',
#   'locus_tag=b0050'],
#  ['ID=cds-NP_414592.1',
#   'Parent=gene-b0050',
#   'Dbxref=UniProtKB/Swiss-Prot:P62672,Genbank:NP_414592.1,ASAP:ABE-0000169,ECOCYC:EG10047,EcoGene:EG10047,GeneID:944772',
#   'Name=NP_414592.1',
#   'gbkey=CDS',
#   'gene=apaG',
#   'locus_tag=b0050',
#   'orig_transcript_id=gnl|b0050|mrna.b0050',
#   'product=DUF525 domain-containing protein ApaG',
#   'protein_id=NP_414592.1',
#   'transl_table=11'],
#  ['ID=gene-b0051',
#   'Dbxref=ASAP:ABE-0000175,ECOCYC:EG10523,EcoGene:EG10523,GeneID:944939',
#   'Name=rsmA',
#   'gbkey=Gene',
#   'gene=rsmA',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0052,ksgA',
#   'locus_tag=b0051'],
#  ['ID=gene-b0052',
#   'Dbxref=ASAP:ABE-0000178,ECOCYC:EG10691,EcoGene:EG10691,GeneID:944919',
#   'Name=pdxA',
#   'gbkey=Gene',
#   'gene=pdxA',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0053',
#   'locus_tag=b0052'],
#  ['ID=cds-NP_414594.1',
#   'Parent=gene-b0052',
#   'Dbxref=UniProtKB/Swiss-Prot:P19624,Genbank:NP_414594.1,ASAP:ABE-0000178,ECOCYC:EG10691,EcoGene:EG10691,GeneID:944919',
#   'Name=NP_414594.1',
#   'gbkey=CDS',
#   'gene=pdxA',
#   'locus_tag=b0052',
#   'orig_transcript_id=gnl|b0052|mrna.b0052',
#   'product=4-hydroxythreonine-4-phosphate dehydrogenase',
#   'protein_id=NP_414594.1',
#   'transl_table=11'],
#  ['ID=gene-b0053',
#   'Dbxref=ASAP:ABE-0000180,ECOCYC:EG10985,EcoGene:EG10985,GeneID:944812',
#   'Name=surA',
#   'gbkey=Gene',
#   'gene=surA',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0054',
#   'locus_tag=b0053'],
#  ['ID=cds-NP_414595.1',
#   'Parent=gene-b0053',
#   'Dbxref=UniProtKB/Swiss-Prot:P0ABZ6,Genbank:NP_414595.1,ASAP:ABE-0000180,ECOCYC:EG10985,EcoGene:EG10985,GeneID:944812',
#   'Name=NP_414595.1',
#   'gbkey=CDS',
#   'gene=surA',
#   'locus_tag=b0053',
#   'orig_transcript_id=gnl|b0053|mrna.b0053',
#   'product=peptidyl-prolyl cis-trans isomerase SurA',
#   'protein_id=NP_414595.1',
#   'transl_table=11'],
#  ['ID=gene-b0054',
#   'Dbxref=ASAP:ABE-0000183,ECOCYC:EG11569,EcoGene:EG11569,GeneID:945011',
#   'Name=lptD',
#   'gbkey=Gene',
#   'gene=lptD',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0055,imp,ostA,yabG',
#   'locus_tag=b0054'],
#  ['ID=cds-NP_414596.1',
#   'Parent=gene-b0054',
#   'Dbxref=UniProtKB/Swiss-Prot:P31554,Genbank:NP_414596.1,ASAP:ABE-0000183,ECOCYC:EG11569,EcoGene:EG11569,GeneID:945011',
#   'Name=NP_414596.1',
#   'gbkey=CDS',
#   'gene=lptD',
#   'locus_tag=b0054',
#   'orig_transcript_id=gnl|b0054|mrna.b0054',
#   'product=lipopolysaccharide assembly protein LptD',
#   'protein_id=NP_414596.1',
#   'transl_table=11'],
#  ['ID=gene-b0055',
#   'Dbxref=ASAP:ABE-0000187,ECOCYC:EG11570,EcoGene:EG11570,GeneID:948992',
#   'Name=djlA',
#   'gbkey=Gene',
#   'gene=djlA',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0056,yabH',
#   'locus_tag=b0055'],
#  ['ID=cds-NP_414597.1',
#   'Parent=gene-b0055',
#   'Dbxref=UniProtKB/Swiss-Prot:P31680,Genbank:NP_414597.1,ASAP:ABE-0000187,ECOCYC:EG11570,EcoGene:EG11570,GeneID:948992',
#   'Name=NP_414597.1',
#   'gbkey=CDS',
#   'gene=djlA',
#   'locus_tag=b0055',
#   'orig_transcript_id=gnl|b0055|mrna.b0055',
#   'product=co-chaperone protein DjlA',
#   'protein_id=NP_414597.1',
#   'transl_table=11'],
#  ['ID=gene-b0056',
#   'Dbxref=ASAP:ABE-0000192,ECOCYC:EG12610,EcoGene:EG12610,GeneID:945039',
#   'Name=yabP',
#   'gbkey=Gene',
#   'gene=yabP',
#   'gene_biotype=protein_coding',
#   'gene_synonym=b4659,ECK0057',
#   'locus_tag=b0056'],
#  ['ID=cds-YP_009518734.1',
#   'Parent=gene-b0056',
#   'Dbxref=UniProtKB/Swiss-Prot:P39220,Genbank:YP_009518734.1,ASAP:ABE-0000192,ECOCYC:EG12610,EcoGene:EG12610,GeneID:945039',
#   'Name=YP_009518734.1',
#   'gbkey=CDS',
#   'gene=yabP',
#   'locus_tag=b0056',
#   'orig_transcript_id=gnl|b0056|mrna.CDS66',
#   'product=putative uncharacterized protein YabP',
#   'protein_id=YP_009518734.1',
#   'transl_table=11'],
#  ['ID=gene-b0057',
#   'Dbxref=ASAP:ABE-0000194,ECOCYC:EG12611,EcoGene:EG12611,GeneID:38094933',
#   'Name=yabQ',
#   'gbkey=Gene',
#   'gene=yabQ',
#   'gene_biotype=protein_coding',
#   'gene_synonym=b4659,ECK0058',
#   'locus_tag=b0057'],
#  ['ID=cds-YP_009518735.1',
#   'Parent=gene-b0057',
#   'Dbxref=UniProtKB/Swiss-Prot:P39221,Genbank:YP_009518735.1,ASAP:ABE-0000194,ECOCYC:EG12611,EcoGene:EG12611,GeneID:38094933',
#   'Name=YP_009518735.1',
#   'gbkey=CDS',
#   'gene=yabQ',
#   'locus_tag=b0057',
#   'orig_transcript_id=gnl|b0057|mrna.CDS67',
#   'product=protein YabQ',
#   'protein_id=YP_009518735.1',
#   'transl_table=11'],
#  ['ID=gene-b0058',
#   'Dbxref=ASAP:ABE-0000196,ECOCYC:EG12609,EcoGene:EG12609,GeneID:946262',
#   'Name=rluA',
#   'gbkey=Gene',
#   'gene=rluA',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0059,yabO',
#   'locus_tag=b0058'],
#  ['ID=cds-NP_414600.1',
#   'Parent=gene-b0058',
#   'Dbxref=UniProtKB/Swiss-Prot:P0AA37,Genbank:NP_414600.1,ASAP:ABE-0000196,ECOCYC:EG12609,EcoGene:EG12609,GeneID:946262',
#   'Name=NP_414600.1',
#   'gbkey=CDS',
#   'gene=rluA',
#   'locus_tag=b0058',
#   'orig_transcript_id=gnl|b0058|mrna.b0058',
#   'product=23S rRNA pseudouridine(746) and tRNA pseudouridine(32) synthase',
#   'protein_id=NP_414600.1',
#   'transl_table=11'],
#  ['ID=gene-b0059',
#   'Dbxref=ASAP:ABE-0000198,ECOCYC:EG11083,EcoGene:EG11083,GeneID:948523',
#   'Name=rapA',
#   'gbkey=Gene',
#   'gene=rapA',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0060,hepA,yabA',
#   'locus_tag=b0059'],
#  ['ID=cds-NP_414601.1',
#   'Parent=gene-b0059',
#   'Dbxref=UniProtKB/Swiss-Prot:P60240,Genbank:NP_414601.1,ASAP:ABE-0000198,ECOCYC:EG11083,EcoGene:EG11083,GeneID:948523',
#   'Name=NP_414601.1',
#   'gbkey=CDS',
#   'gene=rapA',
#   'locus_tag=b0059',
#   'orig_transcript_id=gnl|b0059|mrna.b0059',
#   'product=RNA polymerase-binding ATPase and RNAP recycling factor',
#   'protein_id=NP_414601.1',
#   'transl_table=11'],
#  ['ID=gene-b0060',
#   'Dbxref=ASAP:ABE-0000202,ECOCYC:EG10747,EcoGene:EG10747,GeneID:944779',
#   'Name=polB',
#   'gbkey=Gene',
#   'gene=polB',
#   'gene_biotype=protein_coding',
#   'gene_synonym=dinA,ECK0061',
#   'locus_tag=b0060'],
#  ['ID=cds-NP_414602.1',
#   'Parent=gene-b0060',
#   'Dbxref=UniProtKB/Swiss-Prot:P21189,Genbank:NP_414602.1,ASAP:ABE-0000202,ECOCYC:EG10747,EcoGene:EG10747,GeneID:944779',
#   'Name=NP_414602.1',
#   'gbkey=CDS',
#   'gene=polB',
#   'locus_tag=b0060',
#   'orig_transcript_id=gnl|b0060|mrna.b0060',
#   'product=DNA polymerase II',
#   'protein_id=NP_414602.1',
#   'transl_table=11'],
#  ['ID=gene-b0061',
#   'Dbxref=ASAP:ABE-0000209,ECOCYC:EG10055,EcoGene:EG10055,GeneID:945294',
#   'Name=araD',
#   'gbkey=Gene',
#   'gene=araD',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0062',
#   'locus_tag=b0061'],
#  ['ID=cds-NP_414603.1',
#   'Parent=gene-b0061',
#   'Dbxref=UniProtKB/Swiss-Prot:P08203,Genbank:NP_414603.1,ASAP:ABE-0000209,ECOCYC:EG10055,EcoGene:EG10055,GeneID:945294',
#   'Name=NP_414603.1',
#   'gbkey=CDS',
#   'gene=araD',
#   'locus_tag=b0061',
#   'orig_transcript_id=gnl|b0061|mrna.b0061',
#   'product=L-ribulose-5-phosphate 4-epimerase AraD',
#   'protein_id=NP_414603.1',
#   'transl_table=11'],
#  ['ID=id-136', 'Note=REPv6a', 'gbkey=repeat_region', 'rpt_type=other'],
#  ['ID=id-137', 'Note=REP6b', 'gbkey=repeat_region', 'rpt_type=other'],
#  ['ID=id-138', 'Note=REPv6c', 'gbkey=repeat_region', 'rpt_type=other'],
#  ['ID=id-139', 'Note=REP6d', 'gbkey=repeat_region', 'rpt_type=other'],
#  ['ID=id-140', 'Note=REPv6e', 'gbkey=repeat_region', 'rpt_type=other'],
#  ['ID=id-141', 'Note=REP6f', 'gbkey=repeat_region', 'rpt_type=other'],
#  ['ID=gene-b0062',
#   'Dbxref=ASAP:ABE-0000221,ECOCYC:EG10052,EcoGene:EG10052,GeneID:947511',
#   'Name=araA',
#   'gbkey=Gene',
#   'gene=araA',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0063',
#   'locus_tag=b0062'],
#  ['ID=cds-NP_414604.1',
#   'Parent=gene-b0062',
#   'Dbxref=UniProtKB/Swiss-Prot:P08202,Genbank:NP_414604.1,ASAP:ABE-0000221,ECOCYC:EG10052,EcoGene:EG10052,GeneID:947511',
#   'Name=NP_414604.1',
#   'gbkey=CDS',
#   'gene=araA',
#   'locus_tag=b0062',
#   'orig_transcript_id=gnl|b0062|mrna.b0062',
#   'product=L-arabinose isomerase',
#   'protein_id=NP_414604.1',
#   'transl_table=11'],
#  ['ID=gene-b0063',
#   'Dbxref=ASAP:ABE-0000223,ECOCYC:EG10053,EcoGene:EG10053,GeneID:946017',
#   'Name=araB',
#   'gbkey=Gene',
#   'gene=araB',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0064',
#   'locus_tag=b0063'],
#  ['ID=cds-NP_414605.1',
#   'Parent=gene-b0063',
#   'Dbxref=UniProtKB/Swiss-Prot:P08204,Genbank:NP_414605.1,ASAP:ABE-0000223,ECOCYC:EG10053,EcoGene:EG10053,GeneID:946017',
#   'Name=NP_414605.1',
#   'gbkey=CDS',
#   'gene=araB',
#   'locus_tag=b0063',
#   'orig_transcript_id=gnl|b0063|mrna.b0063',
#   'product=ribulokinase',
#   'protein_id=NP_414605.1',
#   'transl_table=11'],
#  ['ID=gene-b0064',
#   'Dbxref=ASAP:ABE-0000236,ECOCYC:EG10054,EcoGene:EG10054,GeneID:944780',
#   'Name=araC',
#   'gbkey=Gene',
#   'gene=araC',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0065',
#   'locus_tag=b0064'],
#  ['ID=cds-NP_414606.1',
#   'Parent=gene-b0064',
#   'Dbxref=UniProtKB/Swiss-Prot:P0A9E0,Genbank:NP_414606.1,ASAP:ABE-0000236,ECOCYC:EG10054,EcoGene:EG10054,GeneID:944780',
#   'Name=NP_414606.1',
#   'gbkey=CDS',
#   'gene=araC',
#   'locus_tag=b0064',
#   'orig_transcript_id=gnl|b0064|mrna.b0064',
#   'product=DNA-binding transcriptional dual regulator AraC',
#   'protein_id=NP_414606.1',
#   'transl_table=11'],
#  ['ID=gene-b0065',
#   'Dbxref=ASAP:ABE-0000241,ECOCYC:EG11571,EcoGene:EG11571,GeneID:944783',
#   'Name=yabI',
#   'gbkey=Gene',
#   'gene=yabI',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0066',
#   'locus_tag=b0065'],
#  ['ID=cds-NP_414607.1',
#   'Parent=gene-b0065',
#   'Dbxref=UniProtKB/Swiss-Prot:P30149,Genbank:NP_414607.1,ASAP:ABE-0000241,ECOCYC:EG11571,EcoGene:EG11571,GeneID:944783',
#   'Name=NP_414607.1',
#   'gbkey=CDS',
#   'gene=yabI',
#   'locus_tag=b0065',
#   'orig_transcript_id=gnl|b0065|mrna.b0065',
#   'product=DedA family protein YabI',
#   'protein_id=NP_414607.1',
#   'transl_table=11'],
#  ['ID=id-150', 'Note=REP7a', 'gbkey=repeat_region', 'rpt_type=other'],
#  ['ID=id-151', 'Note=REP7b', 'gbkey=repeat_region', 'rpt_type=other'],
#  ['ID=gene-b0066',
#   'Dbxref=ASAP:ABE-0000244,ECOCYC:EG11572,EcoGene:EG11572,GeneID:944785',
#   'Name=thiQ',
#   'gbkey=Gene',
#   'gene=thiQ',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0067,sfuC,yabJ',
#   'locus_tag=b0066'],
#  ['ID=cds-NP_414608.1',
#   'Parent=gene-b0066',
#   'Dbxref=UniProtKB/Swiss-Prot:P31548,Genbank:NP_414608.1,ASAP:ABE-0000244,ECOCYC:EG11572,EcoGene:EG11572,GeneID:944785',
#   'Name=NP_414608.1',
#   'gbkey=CDS',
#   'gene=thiQ',
#   'locus_tag=b0066',
#   'orig_transcript_id=gnl|b0066|mrna.b0066',
#   'product=thiamine ABC transporter ATP binding subunit',
#   'protein_id=NP_414608.1',
#   'transl_table=11'],
#  ['ID=gene-b0067',
#   'Dbxref=ASAP:ABE-0000246,ECOCYC:EG11573,EcoGene:EG11573,GeneID:944784',
#   'Name=thiP',
#   'gbkey=Gene',
#   'gene=thiP',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0068,sfuB,yabK',
#   'locus_tag=b0067'],
#  ['ID=cds-NP_414609.1',
#   'Parent=gene-b0067',
#   'Dbxref=UniProtKB/Swiss-Prot:P31549,Genbank:NP_414609.1,ASAP:ABE-0000246,ECOCYC:EG11573,EcoGene:EG11573,GeneID:944784',
#   'Name=NP_414609.1',
#   'gbkey=CDS',
#   'gene=thiP',
#   'locus_tag=b0067',
#   'orig_transcript_id=gnl|b0067|mrna.b0067',
#   'product=thiamine ABC transporter membrane subunit',
#   'protein_id=NP_414609.1',
#   'transl_table=11'],
#  ['ID=gene-b0068',
#   'Dbxref=ASAP:ABE-0000249,ECOCYC:EG11574,EcoGene:EG11574,GeneID:946306',
#   'Name=thiB',
#   'gbkey=Gene',
#   'gene=thiB',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0069,sfuA,tbpA,yabL',
#   'locus_tag=b0068'],
#  ['ID=cds-NP_414610.1',
#   'Parent=gene-b0068',
#   'Dbxref=UniProtKB/Swiss-Prot:P31550,Genbank:NP_414610.1,ASAP:ABE-0000249,ECOCYC:EG11574,EcoGene:EG11574,GeneID:946306',
#   'Name=NP_414610.1',
#   'gbkey=CDS',
#   'gene=thiB',
#   'locus_tag=b0068',
#   'orig_transcript_id=gnl|b0068|mrna.b0068',
#   'product=thiamine ABC transporter periplasmic binding protein',
#   'protein_id=NP_414610.1',
#   'transl_table=11'],
#  ['ID=gene-b0069',
#   'Dbxref=ASAP:ABE-0000251,ECOCYC:EG12094,EcoGene:EG12094,GeneID:944788',
#   'Name=sgrR',
#   'gbkey=Gene',
#   'gene=sgrR',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0070,yabN',
#   'locus_tag=b0069'],
#  ['ID=cds-NP_414611.1',
#   'Parent=gene-b0069',
#   'Dbxref=UniProtKB/Swiss-Prot:P33595,Genbank:NP_414611.1,ASAP:ABE-0000251,ECOCYC:EG12094,EcoGene:EG12094,GeneID:944788',
#   'Name=NP_414611.1',
#   'gbkey=CDS',
#   'gene=sgrR',
#   'locus_tag=b0069',
#   'orig_transcript_id=gnl|b0069|mrna.b0069',
#   'product=DNA-binding transcriptional dual regulator SgrR',
#   'protein_id=NP_414611.1',
#   'transl_table=11'],
#  ['ID=gene-b4577',
#   'Dbxref=ASAP:ABE-0285090,ECOCYC:G0-9941,EcoGene:EG31149,GeneID:4056038',
#   'Name=sgrS',
#   'gbkey=Gene',
#   'gene=sgrS',
#   'gene_biotype=ncRNA',
#   'gene_synonym=ECK0071,ryaA',
#   'locus_tag=b4577'],
#  ['ID=rna-b4577',
#   'Parent=gene-b4577',
#   'Dbxref=ASAP:ABE-0285090,ECOCYC:G0-9941,EcoGene:EG31149,GeneID:4056038',
#   'gbkey=ncRNA',
#   'gene=sgrS',
#   'locus_tag=b4577',
#   'product=small regulatory RNA SgrS'],
#  ['ID=exon-b4577-1',
#   'Parent=rna-b4577',
#   'Dbxref=ASAP:ABE-0285090,ECOCYC:G0-9941,EcoGene:EG31149,GeneID:4056038',
#   'gbkey=ncRNA',
#   'gene=sgrS',
#   'locus_tag=b4577',
#   'product=small regulatory RNA SgrS'],
#  ['ID=gene-b4662',
#   'Dbxref=ECOCYC:G0-10617,EcoGene:EG14467,GeneID:7751624',
#   'Name=sgrT',
#   'gbkey=Gene',
#   'gene=sgrT',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK4477',
#   'locus_tag=b4662'],
#  ['ID=cds-YP_002791237.1',
#   'Parent=gene-b4662',
#   'Dbxref=UniProtKB/Swiss-Prot:C1P5Z7,Genbank:YP_002791237.1,ECOCYC:G0-10617,EcoGene:EG14467,GeneID:7751624',
#   'Name=YP_002791237.1',
#   'gbkey=CDS',
#   'gene=sgrT',
#   'locus_tag=b4662',
#   'orig_transcript_id=gnl|b4662|mrna.b4662',
#   'product=putative inhibitor of the PtsG glucose transporter',
#   'protein_id=YP_002791237.1',
#   'transl_table=11'],
#  ['ID=gene-b0070',
#   'Dbxref=ASAP:ABE-0000257,ECOCYC:EG11754,EcoGene:EG11754,GeneID:944793',
#   'Name=setA',
#   'gbkey=Gene',
#   'gene=setA',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0072,yabM',
#   'locus_tag=b0070'],
#  ['ID=cds-YP_025293.1',
#   'Parent=gene-b0070',
#   'Dbxref=UniProtKB/Swiss-Prot:P31675,Genbank:YP_025293.1,ASAP:ABE-0000257,ECOCYC:EG11754,EcoGene:EG11754,GeneID:944793',
#   'Name=YP_025293.1',
#   'gbkey=CDS',
#   'gene=setA',
#   'locus_tag=b0070',
#   'orig_transcript_id=gnl|b0070|mrna.b0070',
#   'product=sugar exporter SetA',
#   'protein_id=YP_025293.1',
#   'transl_table=11'],
#  ['ID=gene-b0071',
#   'Dbxref=ASAP:ABE-0000259,ECOCYC:EG11575,EcoGene:EG11575,GeneID:945642',
#   'Name=leuD',
#   'gbkey=Gene',
#   'gene=leuD',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0073',
#   'locus_tag=b0071'],
#  ['ID=cds-NP_414613.1',
#   'Parent=gene-b0071',
#   'Dbxref=UniProtKB/Swiss-Prot:P30126,Genbank:NP_414613.1,ASAP:ABE-0000259,ECOCYC:EG11575,EcoGene:EG11575,GeneID:945642',
#   'Name=NP_414613.1',
#   'gbkey=CDS',
#   'gene=leuD',
#   'locus_tag=b0071',
#   'orig_transcript_id=gnl|b0071|mrna.b0071',
#   'product=3-isopropylmalate dehydratase subunit LeuD',
#   'protein_id=NP_414613.1',
#   'transl_table=11'],
#  ['ID=gene-b0072',
#   'Dbxref=ASAP:ABE-0000261,ECOCYC:EG11576,EcoGene:EG11576,GeneID:945076',
#   'Name=leuC',
#   'gbkey=Gene',
#   'gene=leuC',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0074',
#   'locus_tag=b0072'],
#  ['ID=cds-NP_414614.1',
#   'Parent=gene-b0072',
#   'Dbxref=UniProtKB/Swiss-Prot:P0A6A6,Genbank:NP_414614.1,ASAP:ABE-0000261,ECOCYC:EG11576,EcoGene:EG11576,GeneID:945076',
#   'Name=NP_414614.1',
#   'gbkey=CDS',
#   'gene=leuC',
#   'locus_tag=b0072',
#   'orig_transcript_id=gnl|b0072|mrna.b0072',
#   'product=3-isopropylmalate dehydratase subunit LeuC',
#   'protein_id=NP_414614.1',
#   'transl_table=11'],
#  ['ID=gene-b0073',
#   'Dbxref=ASAP:ABE-0000265,ECOCYC:EG11577,EcoGene:EG11577,GeneID:944798',
#   'Name=leuB',
#   'gbkey=Gene',
#   'gene=leuB',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0075',
#   'locus_tag=b0073'],
#  ['ID=cds-NP_414615.4',
#   'Parent=gene-b0073',
#   'Dbxref=UniProtKB/Swiss-Prot:P30125,Genbank:NP_414615.4,ASAP:ABE-0000265,ECOCYC:EG11577,EcoGene:EG11577,GeneID:944798',
#   'Name=NP_414615.4',
#   'gbkey=CDS',
#   'gene=leuB',
#   'locus_tag=b0073',
#   'orig_transcript_id=gnl|b0073|mrna.b0073',
#   'product=3-isopropylmalate dehydrogenase',
#   'protein_id=NP_414615.4',
#   'transl_table=11'],
#  ['ID=gene-b0074',
#   'Dbxref=ASAP:ABE-0000267,ECOCYC:EG11226,EcoGene:EG11226,GeneID:947465',
#   'Name=leuA',
#   'gbkey=Gene',
#   'gene=leuA',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0076',
#   'locus_tag=b0074'],
#  ['ID=cds-NP_414616.1',
#   'Parent=gene-b0074',
#   'Dbxref=UniProtKB/Swiss-Prot:P09151,Genbank:NP_414616.1,ASAP:ABE-0000267,ECOCYC:EG11226,EcoGene:EG11226,GeneID:947465',
# ...
#   'Name=NP_414952.1',
#   'gbkey=CDS',
#   'gene=pgpA',
#   'locus_tag=b0418',
#   'orig_transcript_id=gnl|b0418|mrna.b0418',
#   'product=phosphatidylglycerophosphatase A',
#   'protein_id=NP_414952.1',
#   'transl_table=11'],
#  ['ID=id-981', 'Note=REP38', 'gbkey=repeat_region', 'rpt_type=other'],
#  ['ID=gene-b0419',
#   'Dbxref=ASAP:ABE-0001457,ECOCYC:G6236,EcoGene:EG13611,GeneID:946903',
#   'Name=yajO',
#   'gbkey=Gene',
#   'gene=yajO',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0413',
#   'locus_tag=b0419'],
#  ['ID=cds-NP_414953.2',
#   'Parent=gene-b0419',
#   'Dbxref=UniProtKB/Swiss-Prot:P77735,Genbank:NP_414953.2,ASAP:ABE-0001457,ECOCYC:G6236,EcoGene:EG13611,GeneID:946903',
#   'Name=NP_414953.2',
#   'gbkey=CDS',
#   'gene=yajO',
#   'locus_tag=b0419',
#   'orig_transcript_id=gnl|b0419|mrna.b0419',
#   'product=1-deoxyxylulose-5-phosphate synthase YajO',
#   'protein_id=NP_414953.2',
#   'transl_table=11'],
#  ['ID=gene-b0420',
#   'Dbxref=ASAP:ABE-0001461,ECOCYC:G6237,EcoGene:EG13612,GeneID:945060',
#   'Name=dxs',
#   'gbkey=Gene',
#   'gene=dxs',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0414,yajP',
#   'locus_tag=b0420'],
#  ['ID=cds-NP_414954.1',
#   'Parent=gene-b0420',
#   'Dbxref=UniProtKB/Swiss-Prot:P77488,Genbank:NP_414954.1,ASAP:ABE-0001461,ECOCYC:G6237,EcoGene:EG13612,GeneID:945060',
#   'Name=NP_414954.1',
#   'gbkey=CDS',
#   'gene=dxs',
#   'locus_tag=b0420',
#   'orig_transcript_id=gnl|b0420|mrna.b0420',
#   'product=1-deoxy-D-xylulose-5-phosphate synthase',
#   'protein_id=NP_414954.1',
#   'transl_table=11'],
#  ['ID=gene-b0421',
#   'Dbxref=ASAP:ABE-0001463,ECOCYC:EG10508,EcoGene:EG10508,GeneID:945064',
#   'Name=ispA',
#   'gbkey=Gene',
#   'gene=ispA',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0415',
#   'locus_tag=b0421'],
#  ['ID=cds-NP_414955.1',
#   'Parent=gene-b0421',
#   'Dbxref=UniProtKB/Swiss-Prot:P22939,Genbank:NP_414955.1,ASAP:ABE-0001463,ECOCYC:EG10508,EcoGene:EG10508,GeneID:945064',
#   'Name=NP_414955.1',
#   'gbkey=CDS',
#   'gene=ispA',
#   'locus_tag=b0421',
#   'orig_transcript_id=gnl|b0421|mrna.b0421',
#   'product=geranyl diphosphate/farnesyl diphosphate synthase',
#   'protein_id=NP_414955.1',
#   'transl_table=11'],
#  ['ID=gene-b0422',
#   'Dbxref=ASAP:ABE-0001466,ECOCYC:EG11098,EcoGene:EG11098,GeneID:945069',
#   'Name=xseB',
#   'gbkey=Gene',
#   'gene=xseB',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0416,yajE',
#   'locus_tag=b0422'],
#  ['ID=cds-NP_414956.1',
#   'Parent=gene-b0422',
#   'Dbxref=UniProtKB/Swiss-Prot:P0A8G9,Genbank:NP_414956.1,ASAP:ABE-0001466,ECOCYC:EG11098,EcoGene:EG11098,GeneID:945069',
#   'Name=NP_414956.1',
#   'gbkey=CDS',
#   'gene=xseB',
#   'locus_tag=b0422',
#   'orig_transcript_id=gnl|b0422|mrna.b0422',
#   'product=exodeoxyribonuclease VII subunit XseB',
#   'protein_id=NP_414956.1',
#   'transl_table=11'],
#  ['ID=gene-b0423',
#   'Dbxref=ASAP:ABE-0001470,ECOCYC:G6238,EcoGene:EG13273,GeneID:945067',
#   'Name=thiI',
#   'gbkey=Gene',
#   'gene=thiI',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0417,nuvA,nuvC,yajK',
#   'locus_tag=b0423'],
#  ['ID=cds-NP_414957.1',
#   'Parent=gene-b0423',
#   'Dbxref=UniProtKB/Swiss-Prot:P77718,Genbank:NP_414957.1,ASAP:ABE-0001470,ECOCYC:G6238,EcoGene:EG13273,GeneID:945067',
#   'Name=NP_414957.1',
#   'gbkey=CDS',
#   'gene=thiI',
#   'locus_tag=b0423',
#   'orig_transcript_id=gnl|b0423|mrna.b0423',
#   'product=tRNA uridine 4-sulfurtransferase',
#   'protein_id=NP_414957.1',
#   'transl_table=11'],
#  ['ID=id-992', 'Note=REP39', 'gbkey=repeat_region', 'rpt_type=other'],
#  ['ID=gene-b0424',
#   'Dbxref=ASAP:ABE-0001472,ECOCYC:G198,EcoGene:EG13272,GeneID:945066',
#   'Name=yajL',
#   'gbkey=Gene',
#   'gene=yajL',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0418,thiJ',
#   'locus_tag=b0424'],
#  ['ID=cds-NP_414958.4',
#   'Parent=gene-b0424',
#   'Dbxref=UniProtKB/Swiss-Prot:Q46948,Genbank:NP_414958.4,ASAP:ABE-0001472,ECOCYC:G198,EcoGene:EG13272,GeneID:945066',
#   'Name=NP_414958.4',
#   'gbkey=CDS',
#   'gene=yajL',
#   'locus_tag=b0424',
#   'orig_transcript_id=gnl|b0424|mrna.b0424',
#   'product=protein/nucleic acid deglycase 3',
#   'protein_id=NP_414958.4',
#   'transl_table=11'],
#  ['ID=gene-b0425',
#   'Dbxref=ASAP:ABE-0001474,ECOCYC:G6239,EcoGene:EG13271,GeneID:945065',
#   'Name=panE',
#   'gbkey=Gene',
#   'gene=panE',
#   'gene_biotype=protein_coding',
#   'gene_synonym=apbA,ECK0419',
#   'locus_tag=b0425'],
#  ['ID=cds-NP_414959.1',
#   'Parent=gene-b0425',
#   'Dbxref=UniProtKB/Swiss-Prot:P0A9J4,Genbank:NP_414959.1,ASAP:ABE-0001474,ECOCYC:G6239,EcoGene:EG13271,GeneID:945065',
#   'Name=NP_414959.1',
#   'gbkey=CDS',
#   'gene=panE',
#   'locus_tag=b0425',
#   'orig_transcript_id=gnl|b0425|mrna.b0425',
#   'product=2-dehydropantoate 2-reductase',
#   'protein_id=NP_414959.1',
#   'transl_table=11'],
#  ['ID=gene-b0426',
#   'Dbxref=ASAP:ABE-0001478,ECOCYC:G6240,EcoGene:EG13613,GeneID:945063',
#   'Name=yajQ',
#   'gbkey=Gene',
#   'gene=yajQ',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0420',
#   'locus_tag=b0426'],
#  ['ID=cds-NP_414960.2',
#   'Parent=gene-b0426',
#   'Dbxref=UniProtKB/Swiss-Prot:P0A8E7,Genbank:NP_414960.2,ASAP:ABE-0001478,ECOCYC:G6240,EcoGene:EG13613,GeneID:945063',
#   'Name=NP_414960.2',
#   'gbkey=CDS',
#   'gene=yajQ',
#   'locus_tag=b0426',
#   'orig_transcript_id=gnl|b0426|mrna.b0426',
#   'product=nucleotide binding protein',
#   'protein_id=NP_414960.2',
#   'transl_table=11'],
#  ['ID=id-999', 'Note=REP40a', 'gbkey=repeat_region', 'rpt_type=other'],
#  ['ID=id-1000', 'Note=REPv40b', 'gbkey=repeat_region', 'rpt_type=other'],
#  ['ID=gene-b0427',
#   'Dbxref=ASAP:ABE-0001481,ECOCYC:G6241,EcoGene:EG13614,GeneID:945058',
#   'Name=yajR',
#   'gbkey=Gene',
#   'gene=yajR',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0421',
#   'locus_tag=b0427'],
#  ['ID=cds-NP_414961.4',
#   'Parent=gene-b0427',
#   'Dbxref=UniProtKB/Swiss-Prot:P77726,Genbank:NP_414961.4,ASAP:ABE-0001481,ECOCYC:G6241,EcoGene:EG13614,GeneID:945058',
#   'Name=NP_414961.4',
#   'gbkey=CDS',
#   'gene=yajR',
#   'locus_tag=b0427',
#   'orig_transcript_id=gnl|b0427|mrna.b0427',
#   'product=putative major facilitator superfamily transport protein YajR',
#   'protein_id=NP_414961.4',
#   'transl_table=11'],
#  ['ID=gene-b0428',
#   'Dbxref=ASAP:ABE-0001484,ECOCYC:EG10182,EcoGene:EG10182,GeneID:945073',
#   'Name=cyoE',
#   'gbkey=Gene',
#   'gene=cyoE',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0422',
#   'locus_tag=b0428'],
#  ['ID=cds-NP_414962.1',
#   'Parent=gene-b0428',
#   'Dbxref=UniProtKB/Swiss-Prot:P0AEA5,Genbank:NP_414962.1,ASAP:ABE-0001484,ECOCYC:EG10182,EcoGene:EG10182,GeneID:945073',
#   'Name=NP_414962.1',
#   'gbkey=CDS',
#   'gene=cyoE',
#   'locus_tag=b0428',
#   'orig_transcript_id=gnl|b0428|mrna.b0428',
#   'product=heme O synthase',
#   'protein_id=NP_414962.1',
#   'transl_table=11'],
#  ['ID=gene-b0429',
#   'Dbxref=ASAP:ABE-0001487,ECOCYC:EG10181,EcoGene:EG10181,GeneID:944918',
#   'Name=cyoD',
#   'gbkey=Gene',
#   'gene=cyoD',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0423',
#   'locus_tag=b0429'],
#  ['ID=cds-NP_414963.1',
#   'Parent=gene-b0429',
#   'Dbxref=UniProtKB/Swiss-Prot:P0ABJ6,Genbank:NP_414963.1,ASAP:ABE-0001487,ECOCYC:EG10181,EcoGene:EG10181,GeneID:944918',
#   'Name=NP_414963.1',
#   'gbkey=CDS',
#   'gene=cyoD',
#   'locus_tag=b0429',
#   'orig_transcript_id=gnl|b0429|mrna.b0429',
#   'product=cytochrome bo3 ubiquinol oxidase subunit 4',
#   'protein_id=NP_414963.1',
#   'transl_table=11'],
#  ['ID=gene-b0430',
#   'Dbxref=ASAP:ABE-0001491,ECOCYC:EG10180,EcoGene:EG10180,GeneID:946897',
#   'Name=cyoC',
#   'gbkey=Gene',
#   'gene=cyoC',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0424',
#   'locus_tag=b0430'],
#  ['ID=cds-NP_414964.1',
#   'Parent=gene-b0430',
#   'Dbxref=UniProtKB/Swiss-Prot:P0ABJ3,Genbank:NP_414964.1,ASAP:ABE-0001491,ECOCYC:EG10180,EcoGene:EG10180,GeneID:946897',
#   'Name=NP_414964.1',
#   'gbkey=CDS',
#   'gene=cyoC',
#   'locus_tag=b0430',
#   'orig_transcript_id=gnl|b0430|mrna.b0430',
#   'product=cytochrome bo3 ubiquinol oxidase subunit 3',
#   'protein_id=NP_414964.1',
#   'transl_table=11'],
#  ['ID=gene-b0431',
#   'Dbxref=ASAP:ABE-0001493,ECOCYC:EG10179,EcoGene:EG10179,GeneID:945615',
#   'Name=cyoB',
#   'gbkey=Gene',
#   'gene=cyoB',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0425',
#   'locus_tag=b0431'],
#  ['ID=cds-NP_414965.1',
#   'Parent=gene-b0431',
#   'Dbxref=UniProtKB/Swiss-Prot:P0ABI8,Genbank:NP_414965.1,ASAP:ABE-0001493,ECOCYC:EG10179,EcoGene:EG10179,GeneID:945615',
#   'Name=NP_414965.1',
#   'gbkey=CDS',
#   'gene=cyoB',
#   'locus_tag=b0431',
#   'orig_transcript_id=gnl|b0431|mrna.b0431',
#   'product=cytochrome bo3 ubiquinol oxidase subunit 1',
#   'protein_id=NP_414965.1',
#   'transl_table=11'],
#  ['ID=gene-b0432',
#   'Dbxref=ASAP:ABE-0001495,ECOCYC:EG10178,EcoGene:EG10178,GeneID:945080',
#   'Name=cyoA',
#   'gbkey=Gene',
#   'gene=cyoA',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0426',
#   'locus_tag=b0432'],
#  ['ID=cds-NP_414966.1',
#   'Parent=gene-b0432',
#   'Dbxref=UniProtKB/Swiss-Prot:P0ABJ1,Genbank:NP_414966.1,ASAP:ABE-0001495,ECOCYC:EG10178,EcoGene:EG10178,GeneID:945080',
#   'Name=NP_414966.1',
#   'gbkey=CDS',
#   'gene=cyoA',
#   'locus_tag=b0432',
#   'orig_transcript_id=gnl|b0432|mrna.b0432',
#   'product=cytochrome bo3 ubiquinol oxidase subunit 2',
#   'protein_id=NP_414966.1',
#   'transl_table=11'],
#  ['ID=gene-b0433',
#   'Dbxref=ASAP:ABE-0001501,ECOCYC:EG12183,EcoGene:EG12183,GeneID:946438',
#   'Name=ampG',
#   'gbkey=Gene',
#   'gene=ampG',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0427',
#   'locus_tag=b0433'],
#  ['ID=cds-NP_414967.1',
#   'Parent=gene-b0433',
#   'Dbxref=UniProtKB/Swiss-Prot:P0AE16,Genbank:NP_414967.1,ASAP:ABE-0001501,ECOCYC:EG12183,EcoGene:EG12183,GeneID:946438',
#   'Name=NP_414967.1',
#   'gbkey=CDS',
#   'gene=ampG',
#   'locus_tag=b0433',
#   'orig_transcript_id=gnl|b0433|mrna.b0433',
#   'product=muropeptide:H(+) symporter',
#   'protein_id=NP_414967.1',
#   'transl_table=11'],
#  ['ID=gene-b0434',
#   'Dbxref=ASAP:ABE-0001504,ECOCYC:EG12182,EcoGene:EG12182,GeneID:945521',
#   'Name=yajG',
#   'gbkey=Gene',
#   'gene=yajG',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0428',
#   'locus_tag=b0434'],
#  ['ID=cds-NP_414968.4',
#   'Parent=gene-b0434',
#   'Dbxref=UniProtKB/Swiss-Prot:P0ADA5,Genbank:NP_414968.4,ASAP:ABE-0001504,ECOCYC:EG12182,EcoGene:EG12182,GeneID:945521',
#   'Name=NP_414968.4',
#   'gbkey=CDS',
#   'gene=yajG',
#   'locus_tag=b0434',
#   'orig_transcript_id=gnl|b0434|mrna.b0434',
#   'product=putative lipoprotein YajG',
#   'protein_id=NP_414968.4',
#   'transl_table=11'],
#  ['ID=gene-b0435',
#   'Dbxref=ASAP:ABE-0001508,ECOCYC:EG10125,EcoGene:EG10125,GeneID:947043',
#   'Name=bolA',
#   'gbkey=Gene',
#   'gene=bolA',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0429',
#   'locus_tag=b0435'],
#  ['ID=cds-NP_414969.4',
#   'Parent=gene-b0435',
#   'Dbxref=UniProtKB/Swiss-Prot:P0ABE2,Genbank:NP_414969.4,ASAP:ABE-0001508,ECOCYC:EG10125,EcoGene:EG10125,GeneID:947043',
#   'Name=NP_414969.4',
#   'gbkey=CDS',
#   'gene=bolA',
#   'locus_tag=b0435',
#   'orig_transcript_id=gnl|b0435|mrna.b0435',
#   'product=DNA-binding transcriptional dual regulator BolA',
#   'protein_id=NP_414969.4',
#   'transl_table=11'],
#  ['ID=gene-b0436',
#   'Dbxref=ASAP:ABE-0001511,ECOCYC:EG11003,EcoGene:EG11003,GeneID:945081',
#   'Name=tig',
#   'gbkey=Gene',
#   'gene=tig',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0430',
#   'locus_tag=b0436'],
#  ['ID=cds-NP_414970.1',
#   'Parent=gene-b0436',
#   'Dbxref=UniProtKB/Swiss-Prot:P0A850,Genbank:NP_414970.1,ASAP:ABE-0001511,ECOCYC:EG11003,EcoGene:EG11003,GeneID:945081',
#   'Name=NP_414970.1',
#   'gbkey=CDS',
#   'gene=tig',
#   'locus_tag=b0436',
#   'orig_transcript_id=gnl|b0436|mrna.b0436',
#   'product=trigger factor',
#   'protein_id=NP_414970.1',
#   'transl_table=11'],
#  ['ID=gene-b0437',
#   'Dbxref=ASAP:ABE-0001515,ECOCYC:EG10158,EcoGene:EG10158,GeneID:945082',
#   'Name=clpP',
#   'gbkey=Gene',
#   'gene=clpP',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0431,lopP',
#   'locus_tag=b0437'],
#  ['ID=cds-NP_414971.1',
#   'Parent=gene-b0437',
#   'Dbxref=UniProtKB/Swiss-Prot:P0A6G7,Genbank:NP_414971.1,ASAP:ABE-0001515,ECOCYC:EG10158,EcoGene:EG10158,GeneID:945082',
#   'Name=NP_414971.1',
#   'gbkey=CDS',
#   'gene=clpP',
#   'locus_tag=b0437',
#   'orig_transcript_id=gnl|b0437|mrna.b0437',
#   'product=ATP-dependent Clp protease proteolytic subunit',
#   'protein_id=NP_414971.1',
#   'transl_table=11'],
#  ['ID=gene-b0438',
#   'Dbxref=ASAP:ABE-0001517,ECOCYC:EG10159,EcoGene:EG10159,GeneID:945083',
#   'Name=clpX',
#   'gbkey=Gene',
#   'gene=clpX',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0432,lopC',
#   'locus_tag=b0438'],
#  ['ID=cds-NP_414972.1',
#   'Parent=gene-b0438',
#   'Dbxref=UniProtKB/Swiss-Prot:P0A6H1,Genbank:NP_414972.1,ASAP:ABE-0001517,ECOCYC:EG10159,EcoGene:EG10159,GeneID:945083',
#   'Name=NP_414972.1',
#   'gbkey=CDS',
#   'gene=clpX',
#   'locus_tag=b0438',
#   'orig_transcript_id=gnl|b0438|mrna.b0438',
#   'product=ATP-dependent Clp protease ATP-binding subunit ClpX',
#   'protein_id=NP_414972.1',
#   'transl_table=11'],
#  ['ID=gene-b0439',
#   'Dbxref=ASAP:ABE-0001521,ECOCYC:EG10542,EcoGene:EG10542,GeneID:945085',
#   'Name=lon',
#   'gbkey=Gene',
#   'gene=lon',
#   'gene_biotype=protein_coding',
#   'gene_synonym=capR,deg,dir,ECK0433,lopA,muc',
#   'locus_tag=b0439'],
#  ['ID=cds-NP_414973.1',
#   'Parent=gene-b0439',
#   'Dbxref=UniProtKB/Swiss-Prot:P0A9M0,Genbank:NP_414973.1,ASAP:ABE-0001521,ECOCYC:EG10542,EcoGene:EG10542,GeneID:945085',
#   'Name=NP_414973.1',
#   'gbkey=CDS',
#   'gene=lon',
#   'locus_tag=b0439',
#   'orig_transcript_id=gnl|b0439|mrna.b0439',
#   'product=Lon protease',
#   'protein_id=NP_414973.1',
#   'transl_table=11'],
#  ['ID=gene-b0440',
#   'Dbxref=ASAP:ABE-0001527,ECOCYC:EG10467,EcoGene:EG10467,GeneID:949095',
#   'Name=hupB',
#   'gbkey=Gene',
#   'gene=hupB',
#   'gene_biotype=protein_coding',
#   'gene_synonym=dbhB,dpeA,ECK0434,hopD',
#   'locus_tag=b0440'],
#  ['ID=cds-NP_414974.1',
#   'Parent=gene-b0440',
#   'Dbxref=UniProtKB/Swiss-Prot:P0ACF4,Genbank:NP_414974.1,ASAP:ABE-0001527,ECOCYC:EG10467,EcoGene:EG10467,GeneID:949095',
#   'Name=NP_414974.1',
#   'gbkey=CDS',
#   'gene=hupB',
#   'locus_tag=b0440',
#   'orig_transcript_id=gnl|b0440|mrna.b0440',
#   'product=DNA-binding protein HU-beta',
#   'protein_id=NP_414974.1',
#   'transl_table=11'],
#  ['ID=gene-b0441',
#   'Dbxref=ASAP:ABE-0001531,ECOCYC:G6242,EcoGene:EG13249,GeneID:946056',
#   'Name=ppiD',
#   'gbkey=Gene',
#   'gene=ppiD',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0435,ybaU',
#   'locus_tag=b0441'],
#  ['ID=cds-NP_414975.1',
#   'Parent=gene-b0441',
#   'Dbxref=UniProtKB/Swiss-Prot:P0ADY1,Genbank:NP_414975.1,ASAP:ABE-0001531,ECOCYC:G6242,EcoGene:EG13249,GeneID:946056',
#   'Name=NP_414975.1',
#   'gbkey=CDS',
#   'gene=ppiD',
#   'locus_tag=b0441',
#   'orig_transcript_id=gnl|b0441|mrna.b0441',
#   'product=periplasmic folding chaperone',
#   'protein_id=NP_414975.1',
#   'transl_table=11'],
#  ['ID=gene-b0442',
#   'Dbxref=ASAP:ABE-0001534,ECOCYC:G6243,EcoGene:EG13250,GeneID:945884',
#   'Name=ybaV',
#   'gbkey=Gene',
#   'gene=ybaV',
#   'gene_biotype=protein_coding',
#   'gene_synonym=comEA,ECK0436',
#   'locus_tag=b0442'],
#  ['ID=cds-NP_414976.1',
#   'Parent=gene-b0442',
#   'Dbxref=UniProtKB/Swiss-Prot:P0AAR8,Genbank:NP_414976.1,ASAP:ABE-0001534,ECOCYC:G6243,EcoGene:EG13250,GeneID:945884',
#   'Name=NP_414976.1',
#   'gbkey=CDS',
#   'gene=ybaV',
#   'locus_tag=b0442',
#   'orig_transcript_id=gnl|b0442|mrna.b0442',
#   'product=helix-hairpin-helix 3 family protein',
#   'protein_id=NP_414976.1',
#   'transl_table=11'],
#  ['ID=gene-b0443',
#   'Dbxref=ASAP:ABE-0001537,ECOCYC:G6244,EcoGene:EG13251,GeneID:945812',
#   'Name=fadM',
#   'gbkey=Gene',
#   'gene=fadM',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0437,tesC,ybaW',
#   'locus_tag=b0443'],
#  ['ID=cds-NP_414977.1',
#   'Parent=gene-b0443',
#   'Dbxref=UniProtKB/Swiss-Prot:P77712,Genbank:NP_414977.1,ASAP:ABE-0001537,ECOCYC:G6244,EcoGene:EG13251,GeneID:945812',
#   'Name=NP_414977.1',
#   'gbkey=CDS',
#   'gene=fadM',
#   'locus_tag=b0443',
#   'orig_transcript_id=gnl|b0443|mrna.b0443',
#   'product=thioesterase III',
#   'protein_id=NP_414977.1',
#   'transl_table=11'],
#  ['ID=id-1035', 'Note=REPt41', 'gbkey=repeat_region', 'rpt_type=other'],
#  ['ID=gene-b0444',
#   'Dbxref=ASAP:ABE-0001539,ECOCYC:G6245,EcoGene:EG13252,GeneID:947034',
#   'Name=queC',
#   'gbkey=Gene',
#   'gene=queC',
#   'gene_biotype=protein_coding',
#   'gene_synonym=ECK0438,ybaX',
#   'locus_tag=b0444'],
#  ...]

# %%
sql='''
SELECT*
FROM sqlite_master
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# type	name	tbl_name	rootpage	sql
# table	sqlite_sequence	sqlite_sequence	3	CREATE TABLE sqlite_sequence(name,seq)
# table	features	features	2	CREATE TABLE features (
#     featureid INTEGER PRIMARY KEY AUTOINCREMENT,
#     seqid CHAR(10),
#     source CHAR(10),
#     type CHAR(10),
#     start INTEGER,
#     end INTEGER,
#     score INTEGER,
#     strand CHAR(10),
#     phase INTEGER,
#     attributes CHAR(10)
#     )
# table	attribites	attribites	4	CREATE TABLE attribites (
#     featureid CHAR(10),
#     tag CHAR(10),
#     value INTEGER,
#     FOREIGN KEY(featureid) REFERENCES features(featureid)
#     )

# %%
sql = '''
SELECT *
FROM sqlite_master
--WHERE name LIKE "attributes";
'''
cursor.execute(sql)
cursor.fetchall()
# Out:
# [('table',
#   'sqlite_sequence',
#   'sqlite_sequence',
#   3,
#   'CREATE TABLE sqlite_sequence(name,seq)'),
#  ('table',
#   'features',
#   'features',
#   2,
#   'CREATE TABLE features (\n    featureid INTEGER PRIMARY KEY AUTOINCREMENT,\n    seqid CHAR(10),\n    source CHAR(10),\n    type CHAR(10), \n    start INTEGER,\n    end INTEGER,\n    score INTEGER,\n    strand CHAR(10),\n    phase INTEGER,\n    attributes CHAR(10)\n    )'),
#  ('table',
#   'attributes',
#   'attributes',
#   4,
#   'CREATE TABLE attributes (\n    featureid CHAR(10),\n    tag CHAR(10),\n    value INTEGER,\n    FOREIGN KEY(featureid) REFERENCES features(featureid)\n    )')]

# %%
with open ('Ecoli_ASM584v2_genomic.gff', 'r') as Ecoli:
    for line in Ecoli:
        if not line.startswith('#') == True:
        data=line.split()
        cursor.execute('INSERT INTO features(\
    seqid, \
    source,\
    type,\
    start,\
    end,\
    score,\
    strand,\
    phase)\
    V)

# %%
sql = '''
INSERT INTO features (seqid,source,type,start,end,score,strand,phase) 
VALUES (?,?,?,?,?,?,?,?);
'''
cursor.executemany(sql,data)
connection.commit()

# %%
sql = '''
INSERT INTO attributes (featureid, tag, value) 
VALUES (?,?,?);
'''
cursor.executemany(sql,data)
connection.commit()

# %%
INSERT INTO features(
    seqid,
    source,
    type,
    start,
    end,
    score,
    strand,
    phase)

# %%
sql='''
    INSERT INTO features(
    seqid,
    source,
    type,
    start,
    end,
    score,
    strand,
    phase)
    VALUES(

# %%
sql='''
    INSERT INTO features(
    seqid,
    source,
    type,
    start,
    end,
    score,
    strand,
    phase)
    VALUES(
    for row in data.iterrows():
        row[0],
        row[1],
        row[3],
        row[4],
        row[5],
        row[6],
        row[7],
        row[8]); 
    '''
cursor.execute(sql)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-67-f5dccf1b92c2> in <module>
#      20         row[8]);
#      21     '''
# ---> 22 cursor.execute(sql)
#
# OperationalError: near "row": syntax error
